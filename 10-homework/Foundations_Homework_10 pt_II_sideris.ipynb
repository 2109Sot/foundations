# %%
#sideris

# %% [markdown]
# # Foundations, Homework 10 pt II
# ## DOHMH New York City Restaurant Inspection Results

# %% [markdown]
# #### Summary
#
# This dataset provides restaurant inspections, violations, grades and adjudication information.
#
# #### Files
#
# - DOHMH_New_York_City_Restaurant_Inspection_Results.csv
# - Restaurant_Inspection_Open_Data_Dictionary_082214.xlsx, "NYC OpenData Data Dictionary"

# %% [markdown]
# ## Where did the dataset come from?

# %%
# NYC OpenData: https://data.cityofnewyork.us/Health/DOHMH-New-York-City-Restaurant-Inspection-Results/xx67-kt59

# %% [markdown]
# ## If I had questions about this dataset, who would I ask?

# %%
# The .xlsx file mentioned in the introduction of the exercise.

# %% [markdown]
# ## Open the dataset using pandas.

# %%
import pandas as pd

# %%
df = pd.read_csv("DOHMH_New_York_City_Restaurant_Inspection_Results.csv")

# %%
df
# Out:
#            CAMIS                                   DBA           BORO  \
# 0       50041401                           FUSION EAST       BROOKLYN
# 1       50016055                      SHANGHAI CUISINE      MANHATTAN
# 2       50014728                         EMPIRE GARDEN      MANHATTAN
# 3       40395858                      TEQUILLA SUNRISE         QUEENS
# 4       41624602                                LE PIF      MANHATTAN
# 5       41380885                     MAMA TINA'S PIZZA      MANHATTAN
# 6       41427038                              WARD III      MANHATTAN
# 7       50060495                           Cafe Hestia      MANHATTAN
# 8       50035808                     THE BLACK ROSE NY      MANHATTAN
# 9       41335375                    COPPOLA'S PIZZERIA         QUEENS
# 10      41356229                    INCHEON RESTAURANT         QUEENS
# 11      50002580                       OCHE A TU GUSTO      MANHATTAN
# ...

# %% [markdown]
# ## How many columns and rows does it have?

# %%
df.shape
# Out:
# (413174, 18)

# %% [markdown]
# ## What are the data types of each column?

# %%
df.dtypes
# Out:
# CAMIS                      int64
# DBA                       object
# BORO                      object
# BUILDING                  object
# STREET                    object
# ZIPCODE                  float64
# PHONE                     object
# CUISINE DESCRIPTION       object
# INSPECTION DATE           object
# ACTION                    object
# VIOLATION CODE            object
# VIOLATION DESCRIPTION     object
# CRITICAL FLAG             object
# SCORE                    float64
# GRADE                     object
# GRADE DATE                object
# RECORD DATE               object
# INSPECTION TYPE           object
# dtype: object

# %% [markdown]
# ## Tell me what four of the columns mean, and state whether you made up the definitions or used a data dictionary.

# %%
# Definitions according to the data dictionary (.xlsx file):

# BUILDING: This field represents the building number for the entity (restaurant).
# VIOLATION CODE: This field represents each violation associated with a restaurant inspection.
# CRITICAL FLAG (3 expected values): Critical violations are those most likely to contribute to foodborne illness.
# GRADE: This field represents the grade associated with this inspection. Grades given during a reopening inspection are derived from the previous re-inspection.

# %% [markdown]
# ## Write five questions you could ask the data.

# %%
# How many of violations have contributed to foodborne illness?
# Which boro has the highest number of violations? Also, what type of cuisine?
# How many cases involve mice? 
# What is the most common inspection type?
# Graph the worst restaurants according to their score.
