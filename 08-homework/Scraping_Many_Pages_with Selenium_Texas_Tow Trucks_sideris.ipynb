# %% [markdown]
# # Texas Tow Trucks (`.apply` and Selenium)
#
# We're going to scrape some [tow trucks in Texas](https://www.tdlr.texas.gov/tools_search/).
#
# Try searching for the TLDR Number `006179570C`.

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### What URL will Selenium be starting on?
#
# - Tip: The answer is *not* `https://www.tdlr.texas.gov/tools_search/`

# %%
# https://www.tdlr.texas.gov/tools_search/mccs_search.asp

# %% [markdown]
# ### Why are you using Selenium for this?

# %%
# Selenium is working well for the first df (3 trucks), but as Soma said in the video "we don't have to," 
# because we can search by adding the code of each truck at the end of the URL, which is what I did for the second
# df (19 trucks).

# %% [markdown]
# ## Scrape this page
#
# Scrape this page, displaying the
#
# - The business name
# - Phone number
# - License status
# - Physical address
#
# **You should know how to do `.post` requests by now.**
#
# - *TIP: For physical address, **ask me on the board** and I'll give you a secret trick about situations like this.*

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()
driver.get('https://www.tdlr.texas.gov/tools_search/mccs_search.asp')

# %%
DLR_number_box = driver.find_element_by_xpath('//*[@id="mcrdata"]')
DLR_number_box.send_keys("006179570C")

# %%
search_button = driver.find_element_by_xpath('//*[@id="submit3"]')
search_button.click()

# %%
business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]')
business_name.text.replace("Name:", "").strip()
# Out:
# 'B.D. SMITH TOWING'

# %%
business_phone = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]')
business_phone.text.replace("Phone:", "").strip()
# Out:
# '8173330706'

# %%
license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]')
license_status.text.replace("Status:", "").strip()
# Out:
# 'Active'

# %%
physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]')
physical_address.text
print(physical_address.text.split(":")[-1].strip())
# Out:
# 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179

# %% [markdown]
# # Using .apply to find data about SEVERAL tow truck companies
#
# The file `trucks-subset.csv` has information about the trucks, we'll use it to find the pages to scrape.
#
# ### Open up `trucks-subset.csv` and save it into a dataframe

# %%
import pandas as pd
df = pd.read_csv("trucks-subset.csv")
df.head()
# Out:
#   TDLR Number
# 0  006507931C
# 1  006179570C
# 2  006502097C

# %% [markdown]
# ### Open up `trucks-subset.csv` in a text editor, then look at your dataframe. Is something different about them? If so, make them match.
#
# - *TIP: I can help with this.*

# %%
# :)

# %% [markdown]
# ## Use `.apply` to go through each row of the dataset, printing out information about each tow truck company.
#
# - The business name
# - Phone number
# - License status
# - Physical address
#
# Just print it out for now.
#
# - *TIP: use .apply and a function*
# - *TIP: If you need help with .apply, look at the "Using apply in pandas" notebook *

# %%
def process_truck(row):
    driver.get('https://www.tdlr.texas.gov/tools_search/mccs_search.asp')
    DLR_number_box = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    DLR_number_box.send_keys(row['TDLR Number'])
    driver.find_element_by_xpath('//*[@id="submit3"]').click()
    business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]')
    print('Name:', business_name.text.replace("Name:", "").strip())
    business_phone = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]')
    print('Phone:', business_phone.text.replace("Phone:", "").strip())
    license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]')
    print('License_status:', license_status.text.replace("Status:", "").strip())
    physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]')
    print('Address:', physical_address.text.split(":")[-1].strip())
    print("-----")
    
df.apply(process_truck, axis=1)
# Out:
# Name: AUGUSTUS E SMITH
# Phone: 9032276464
# License_status: Active
# Address: 103 N MAIN ST
# BONHAM, TX. 75418
# -----
# Name: B.D. SMITH TOWING
# Phone: 8173330706
# License_status: Active
# Address: 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179
# -----
# Name: BARRY MICHAEL SMITH
# Phone: 8066544404
# License_status: Active
# Address: 4501 W CEMETERY RD
# CANYON, TX. 79015
# -----
# 0    None
# 1    None
# 2    None
# dtype: object

# %% [markdown]
# ## Scrape the following information for each row of the dataset, and save it into new columns in your dataframe.
#
# - The business name
# - Phone number
# - License status
# - Physical address
#
# It's basically what we did before, but using the function a little differently.
#
# - *TIP: Use .apply and a function*
# - *TIP: Remember to use `return`*

# %%
def process_truck(row):
    driver.get('https://www.tdlr.texas.gov/tools_search/mccs_search.asp')
    DLR_number_box = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    DLR_number_box.send_keys(row['TDLR Number'])
    driver.find_element_by_xpath('//*[@id="submit3"]').click()
    business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]')
    print('Name:', business_name.text.replace("Name:", "").strip())
    business_phone = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]')
    print('Phone:', business_phone.text.replace("Phone:", "").strip())
    license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]')
    print('License_status:', license_status.text.replace("Status:", "").strip())
    physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]')
    print('Address:', physical_address.text.split(":")[-1].strip())
    print("-----")
    
    return pd.Series ({
        'Name': business_name.text.replace("Name:", "").strip(),
        'Phone': business_phone.text.replace("Phone:", "").strip(),
        'License status': license_status.text.replace("Status:", "").strip(),
        'Address': physical_address.text.split(":")[-1].strip()
    })
    
new_df = df.apply(process_truck, axis=1).join(df)
new_df
# Out:
# Name: AUGUSTUS E SMITH
# Phone: 9032276464
# License_status: Active
# Address: 103 N MAIN ST
# BONHAM, TX. 75418
# -----
# Name: AUGUSTUS E SMITH
# Phone: 9032276464
# License_status: Active
# Address: 103 N MAIN ST
# BONHAM, TX. 75418
# -----
# Name: B.D. SMITH TOWING
# Phone: 8173330706
# License_status: Active
# Address: 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179
# -----
# Name: BARRY MICHAEL SMITH
# Phone: 8066544404
# License_status: Active
# Address: 4501 W CEMETERY RD
# CANYON, TX. 79015
# -----
#                                           Address License status  \
# 0                103 N MAIN ST\nBONHAM, TX. 75418         Active
# 1  13619 BRETT JACKSON RD.\nFORT WORTH, TX. 76179         Active
# 2           4501 W CEMETERY RD\nCANYON, TX. 79015         Active
#
#                   Name       Phone TDLR Number
# 0     AUGUSTUS E SMITH  9032276464  006507931C
# 1    B.D. SMITH TOWING  8173330706  006179570C
# 2  BARRY MICHAEL SMITH  8066544404  006502097C

# %% [markdown]
# ### Save your dataframe as a CSV

# %%
new_df.to_csv("trucks-new.csv", index=False)

# %% [markdown]
# ### Re-open your dataframe to confirm you didn't save any extra weird columns

# %%
pd.read_csv("trucks-new.csv")
# Out:
#                                           Address License status  \
# 0                103 N MAIN ST\nBONHAM, TX. 75418         Active
# 1  13619 BRETT JACKSON RD.\nFORT WORTH, TX. 76179         Active
# 2           4501 W CEMETERY RD\nCANYON, TX. 79015         Active
#
#                   Name       Phone TDLR Number
# 0     AUGUSTUS E SMITH  9032276464  006507931C
# 1    B.D. SMITH TOWING  8173330706  006179570C
# 2  BARRY MICHAEL SMITH  8066544404  006502097C

# %% [markdown]
# ## Repeat this process for the entire `tow-trucks.csv` file

# %%
tow_df = pd.read_csv("tow-trucks.csv")
tow_df
# Out:
#    TDLR Number
# 0   006507931C
# 1   006179570C
# 2   006502097C
# 3   006494912C
# 4   0649468VSF
# 5   006448786C
# 6   0648444VSF
# 7   0651667VSF
# 8   006017767C
# 9   006495492C
# 10  006518521C
# 11  006521662C
# 12  006482451C
# 13  0646264VSF
# 14  0650690VSF
# 15  006505010C
# 16  0000210VSF
# 17  005029369C
# 18  006410509C
# 19  0643482VSF

# %%
def process_truck(row):
    driver.get('https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=' + row['TDLR Number'])
    #DLR_number_box = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    #DLR_number_box.send_keys(row['TDLR Number'])
    #driver.find_element_by_xpath('//*[@id="submit3"]').click()
    business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]')
    print('Name:', business_name.text.replace("Name:", "").strip())
    business_phone = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]')
    print('Phone:', business_phone.text.replace("Phone:", "").strip())
    license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]')
    print('License_status:', license_status.text.replace("Status:", "").strip())
    physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]')
    print('Address:', physical_address.text.split(":")[-1].strip())
    print("-----")
    
tow_df.apply(process_truck, axis=1)
# Out:
# Name: AUGUSTUS E SMITH
# Phone: 9032276464
# License_status: Active
# Address: 103 N MAIN ST
# BONHAM, TX. 75418
# -----
# Name: B.D. SMITH TOWING
# Phone: 8173330706
# License_status: Active
# Address: 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179
# -----
# Name: BARRY MICHAEL SMITH
# Phone: 8066544404
# License_status: Active
# Address: 4501 W CEMETERY RD
# CANYON, TX. 79015
# -----
# Name: HEATH SMITH
# Phone: 940-552-0687
# License_status: Expired
# Address: 1529 WILBARGER ST
# VERNON, TX. 76384
# -----
# Name: HEATH SMITH
# Phone: 9405520687
# License_status: Expired
# Address: 1529 WILBARGER ST
# VERNON, TX. 76384
# -----
# Name: HYSMITH AUTOMOTIVE
# Phone: Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# License_status: Active
# Address: 1210 US 380 BYPASS
# GRAHAM, TX. 76450
# -----
# Name: HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# Phone: Owner/Officer:   WILLIAM THOMAS HYSMITH / PRESIDENT
# License_status: Expired
# Address: 927 LOVING HWY
# GRAHAM, TX. 76450
# -----
# Name: HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# Phone: Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# License_status: Active
# Address: 1210 380 BYPASS
# GRAHAM, TX. 76450
# -----
# Name: JEFF & WENDY SMITH
# Phone: Owner/Officer:   WENDY SMITH / PARTNER
# License_status: Expired
# Address: 10842 FM 2138 N
# JACKSONVILLE, TX. 75766
# -----
# Name: JEFF SMITH
# Phone: 8324354670
# License_status: Active
# Address: 4338 HARVEY RD
# CROSBY, TX. 77532
# -----
# Name: LUTHER SMITH
# Phone: 281-838-9435
# License_status: Active
# Address: 20001 FM 2100 RD
# CROSBY, TX. 77532
# -----
# Name: MAURICE SMITH
# Phone: 7134544462
# License_status: Active
# Address: 5505 SAVANNAH WOODS LN
# ROSHARON, TX. 77583
# -----
# Name: METRO LOCKSMITHS INC
# Phone: Owner/Officer:   SOCORRO M ARREOLA / OWNER
# License_status: Active
# Address: 200 S WALL ST
# ITASCA, TX. 76055
# -----
# Name: RICKY SMITH
# Phone: 9364997917
# License_status: Suspended
# Address: 115 CARTWRIGHT
# CONROE, TX. 77301
# -----
# Name: RICKY SMITH
# Phone: 9364997917
# License_status: Suspended
# Address: 11426 FOSTORIA RD
# CLEVELAND, TX. 77328
# -----
# Name: SAMMY L SMITH
# Phone: 3252159496
# License_status: Expired
# Address: 355 N 16TH ST
# JUNCTION, TX. 76849
# -----
# Name: SMITH BRO. WRECKER SERVICE
# Phone: Owner/Officer:   GLEN SMITH / PARTNER
# License_status: Active
# Address: 10842 FM 2138 N
# JACKSONVILLE, TX. 75766
# -----
# Name: SMITH BROS. WRECKER SERVICE
# Phone: Owner/Officer:   GLEN SMITH / PARTNER
# License_status: Active
# Address: 10842 FM 2138 N
# JACKSONVILLE, TX. 75766
# -----
# Name: SMITH TOWING & RECOVERY, LLC
# Phone: 9362693915
# License_status: Active
# Address: 12741 HWY 84E
# JOAQUIN, TX. 75954
# -----
# Name: SMITH TOWING & RECOVERY,LLC
# Phone: 9362693915
# License_status: Active
# Address: 12741 HWY 84 E
# JOAQUIN, TX. 75954
# -----
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# dtype: object

# %%
def process_truck(row):
    driver.get('https://www.tdlr.texas.gov/tools_search/mccs_display.asp?mcrnumber=' + row['TDLR Number'])
    #DLR_number_box = driver.find_element_by_xpath('//*[@id="mcrdata"]')
    #DLR_number_box.send_keys(row['TDLR Number'])
    #driver.find_element_by_xpath('//*[@id="submit3"]').click()
    business_name = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[2]/td[1]')
    print('Name:', business_name.text.replace("Name:", "").strip())
    business_phone = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[2]/tbody/tr[4]/td[1]')
    print('Phone:', business_phone.text.replace("Phone:", "").strip())
    license_status = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[1]/td[2]')
    print('License_status:', license_status.text.replace("Status:", "").strip())
    physical_address = driver.find_element_by_xpath('//*[@id="t1"]/tbody/tr/td/font/table[3]/tbody/tr[2]/td[2]')
    print('Address:', physical_address.text.split(":")[-1].strip())
    print("-----")
    
    return pd.Series ({
        'Name': business_name.text.replace("Name:", "").strip(),
        'Phone': business_phone.text.replace("Phone:", "").strip(),
        'License status': license_status.text.replace("Status:", "").strip(),
        'Address': physical_address.text.split(":")[-1].strip()
    })
    
final_df = tow_df.apply(process_truck, axis=1).join(tow_df)
final_df
# Out:
# Name: AUGUSTUS E SMITH
# Phone: 9032276464
# License_status: Active
# Address: 103 N MAIN ST
# BONHAM, TX. 75418
# -----
# Name: AUGUSTUS E SMITH
# Phone: 9032276464
# License_status: Active
# Address: 103 N MAIN ST
# BONHAM, TX. 75418
# -----
# Name: B.D. SMITH TOWING
# Phone: 8173330706
# License_status: Active
# Address: 13619 BRETT JACKSON RD.
# FORT WORTH, TX. 76179
# -----
# Name: BARRY MICHAEL SMITH
# Phone: 8066544404
# License_status: Active
# Address: 4501 W CEMETERY RD
# CANYON, TX. 79015
# -----
# Name: HEATH SMITH
# Phone: 940-552-0687
# License_status: Expired
# Address: 1529 WILBARGER ST
# VERNON, TX. 76384
# -----
# Name: HEATH SMITH
# Phone: 9405520687
# License_status: Expired
# Address: 1529 WILBARGER ST
# VERNON, TX. 76384
# -----
# Name: HYSMITH AUTOMOTIVE
# Phone: Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# License_status: Active
# Address: 1210 US 380 BYPASS
# GRAHAM, TX. 76450
# -----
# Name: HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# Phone: Owner/Officer:   WILLIAM THOMAS HYSMITH / PRESIDENT
# License_status: Expired
# Address: 927 LOVING HWY
# GRAHAM, TX. 76450
# -----
# Name: HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# Phone: Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER
# License_status: Active
# Address: 1210 380 BYPASS
# GRAHAM, TX. 76450
# -----
# Name: JEFF & WENDY SMITH
# Phone: Owner/Officer:   WENDY SMITH / PARTNER
# License_status: Expired
# Address: 10842 FM 2138 N
# JACKSONVILLE, TX. 75766
# -----
# Name: JEFF SMITH
# Phone: 8324354670
# License_status: Active
# Address: 4338 HARVEY RD
# CROSBY, TX. 77532
# -----
# Name: LUTHER SMITH
# Phone: 281-838-9435
# License_status: Active
# Address: 20001 FM 2100 RD
# CROSBY, TX. 77532
# -----
# Name: MAURICE SMITH
# Phone: 7134544462
# License_status: Active
# Address: 5505 SAVANNAH WOODS LN
# ROSHARON, TX. 77583
# -----
# Name: METRO LOCKSMITHS INC
# Phone: Owner/Officer:   SOCORRO M ARREOLA / OWNER
# License_status: Active
# Address: 200 S WALL ST
# ITASCA, TX. 76055
# -----
# Name: RICKY SMITH
# Phone: 9364997917
# License_status: Suspended
# Address: 115 CARTWRIGHT
# CONROE, TX. 77301
# -----
# Name: RICKY SMITH
# Phone: 9364997917
# License_status: Suspended
# Address: 11426 FOSTORIA RD
# CLEVELAND, TX. 77328
# -----
# Name: SAMMY L SMITH
# Phone: 3252159496
# License_status: Expired
# Address: 355 N 16TH ST
# JUNCTION, TX. 76849
# -----
# Name: SMITH BRO. WRECKER SERVICE
# Phone: Owner/Officer:   GLEN SMITH / PARTNER
# License_status: Active
# Address: 10842 FM 2138 N
# JACKSONVILLE, TX. 75766
# -----
# Name: SMITH BROS. WRECKER SERVICE
# Phone: Owner/Officer:   GLEN SMITH / PARTNER
# License_status: Active
# Address: 10842 FM 2138 N
# JACKSONVILLE, TX. 75766
# -----
# Name: SMITH TOWING & RECOVERY, LLC
# Phone: 9362693915
# License_status: Active
# Address: 12741 HWY 84E
# JOAQUIN, TX. 75954
# -----
# Name: SMITH TOWING & RECOVERY,LLC
# Phone: 9362693915
# License_status: Active
# Address: 12741 HWY 84 E
# JOAQUIN, TX. 75954
# -----
#                                            Address License status  \
# 0                 103 N MAIN ST\nBONHAM, TX. 75418         Active
# 1   13619 BRETT JACKSON RD.\nFORT WORTH, TX. 76179         Active
# 2            4501 W CEMETERY RD\nCANYON, TX. 79015         Active
# 3             1529 WILBARGER ST\nVERNON, TX. 76384        Expired
# 4             1529 WILBARGER ST\nVERNON, TX. 76384        Expired
# 5            1210 US 380 BYPASS\nGRAHAM, TX. 76450         Active
# 6                927 LOVING HWY\nGRAHAM, TX. 76450        Expired
# 7               1210 380 BYPASS\nGRAHAM, TX. 76450         Active
# 8         10842 FM 2138 N\nJACKSONVILLE, TX. 75766        Expired
# 9                4338 HARVEY RD\nCROSBY, TX. 77532         Active
# 10             20001 FM 2100 RD\nCROSBY, TX. 77532         Active
# 11     5505 SAVANNAH WOODS LN\nROSHARON, TX. 77583         Active
# 12                200 S WALL ST\nITASCA, TX. 76055         Active
# 13               115 CARTWRIGHT\nCONROE, TX. 77301      Suspended
# 14         11426 FOSTORIA RD\nCLEVELAND, TX. 77328      Suspended
# 15              355 N 16TH ST\nJUNCTION, TX. 76849        Expired
# 16        10842 FM 2138 N\nJACKSONVILLE, TX. 75766         Active
# 17        10842 FM 2138 N\nJACKSONVILLE, TX. 75766         Active
# 18               12741 HWY 84E\nJOAQUIN, TX. 75954         Active
# 19              12741 HWY 84 E\nJOAQUIN, TX. 75954         Active
#
#                                      Name  \
# 0                        AUGUSTUS E SMITH
# 1                       B.D. SMITH TOWING
# 2                     BARRY MICHAEL SMITH
# 3                             HEATH SMITH
# 4                             HEATH SMITH
# 5                      HYSMITH AUTOMOTIVE
# 6   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 7   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 8                      JEFF & WENDY SMITH
# 9                              JEFF SMITH
# 10                           LUTHER SMITH
# 11                          MAURICE SMITH
# 12                   METRO LOCKSMITHS INC
# 13                            RICKY SMITH
# 14                            RICKY SMITH
# 15                          SAMMY L SMITH
# 16             SMITH BRO. WRECKER SERVICE
# 17            SMITH BROS. WRECKER SERVICE
# 18           SMITH TOWING & RECOVERY, LLC
# 19            SMITH TOWING & RECOVERY,LLC
#
#                                                 Phone TDLR Number
# 0                                          9032276464  006507931C
# 1                                          8173330706  006179570C
# 2                                          8066544404  006502097C
# 3                                        940-552-0687  006494912C
# 4                                          9405520687  0649468VSF
# 5    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER  006448786C
# 6   Owner/Officer:   WILLIAM THOMAS HYSMITH / PRES...  0648444VSF
# 7    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER  0651667VSF
# 8              Owner/Officer:   WENDY SMITH / PARTNER  006017767C
# 9                                          8324354670  006495492C
# 10                                       281-838-9435  006518521C
# 11                                         7134544462  006521662C
# 12         Owner/Officer:   SOCORRO M ARREOLA / OWNER  006482451C
# 13                                         9364997917  0646264VSF
# 14                                         9364997917  0650690VSF
# 15                                         3252159496  006505010C
# 16              Owner/Officer:   GLEN SMITH / PARTNER  0000210VSF
# 17              Owner/Officer:   GLEN SMITH / PARTNER  005029369C
# 18                                         9362693915  006410509C
# 19                                         9362693915  0643482VSF

# %%
final_df.to_csv("trucks-final.csv", index=False)

# %%
pd.read_csv("trucks-final.csv")
# Out:
#                                            Address License status  \
# 0                 103 N MAIN ST\nBONHAM, TX. 75418         Active
# 1   13619 BRETT JACKSON RD.\nFORT WORTH, TX. 76179         Active
# 2            4501 W CEMETERY RD\nCANYON, TX. 79015         Active
# 3             1529 WILBARGER ST\nVERNON, TX. 76384        Expired
# 4             1529 WILBARGER ST\nVERNON, TX. 76384        Expired
# 5            1210 US 380 BYPASS\nGRAHAM, TX. 76450         Active
# 6                927 LOVING HWY\nGRAHAM, TX. 76450        Expired
# 7               1210 380 BYPASS\nGRAHAM, TX. 76450         Active
# 8         10842 FM 2138 N\nJACKSONVILLE, TX. 75766        Expired
# 9                4338 HARVEY RD\nCROSBY, TX. 77532         Active
# 10             20001 FM 2100 RD\nCROSBY, TX. 77532         Active
# 11     5505 SAVANNAH WOODS LN\nROSHARON, TX. 77583         Active
# 12                200 S WALL ST\nITASCA, TX. 76055         Active
# 13               115 CARTWRIGHT\nCONROE, TX. 77301      Suspended
# 14         11426 FOSTORIA RD\nCLEVELAND, TX. 77328      Suspended
# 15              355 N 16TH ST\nJUNCTION, TX. 76849        Expired
# 16        10842 FM 2138 N\nJACKSONVILLE, TX. 75766         Active
# 17        10842 FM 2138 N\nJACKSONVILLE, TX. 75766         Active
# 18               12741 HWY 84E\nJOAQUIN, TX. 75954         Active
# 19              12741 HWY 84 E\nJOAQUIN, TX. 75954         Active
#
#                                      Name  \
# 0                        AUGUSTUS E SMITH
# 1                       B.D. SMITH TOWING
# 2                     BARRY MICHAEL SMITH
# 3                             HEATH SMITH
# 4                             HEATH SMITH
# 5                      HYSMITH AUTOMOTIVE
# 6   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 7   HYSMITH AUTOMOTIVE & TRUCK REPAIR INC
# 8                      JEFF & WENDY SMITH
# 9                              JEFF SMITH
# 10                           LUTHER SMITH
# 11                          MAURICE SMITH
# 12                   METRO LOCKSMITHS INC
# 13                            RICKY SMITH
# 14                            RICKY SMITH
# 15                          SAMMY L SMITH
# 16             SMITH BRO. WRECKER SERVICE
# 17            SMITH BROS. WRECKER SERVICE
# 18           SMITH TOWING & RECOVERY, LLC
# 19            SMITH TOWING & RECOVERY,LLC
#
#                                                 Phone TDLR Number
# 0                                          9032276464  006507931C
# 1                                          8173330706  006179570C
# 2                                          8066544404  006502097C
# 3                                        940-552-0687  006494912C
# 4                                          9405520687  0649468VSF
# 5    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER  006448786C
# 6   Owner/Officer:   WILLIAM THOMAS HYSMITH / PRES...  0648444VSF
# 7    Owner/Officer:   ASHLEY ERIN HYSMITH / TREASURER  0651667VSF
# 8              Owner/Officer:   WENDY SMITH / PARTNER  006017767C
# 9                                          8324354670  006495492C
# 10                                       281-838-9435  006518521C
# 11                                         7134544462  006521662C
# 12         Owner/Officer:   SOCORRO M ARREOLA / OWNER  006482451C
# 13                                         9364997917  0646264VSF
# 14                                         9364997917  0650690VSF
# 15                                         3252159496  006505010C
# 16              Owner/Officer:   GLEN SMITH / PARTNER  0000210VSF
# 17              Owner/Officer:   GLEN SMITH / PARTNER  005029369C
# 18                                         9362693915  006410509C
# 19                                         9362693915  0643482VSF
