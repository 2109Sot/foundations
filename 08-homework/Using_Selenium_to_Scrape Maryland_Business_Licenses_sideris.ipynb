# %% [markdown]
# # Scraping Maryland Business Licenses with Selenium
#
# Maryland has a [great portal](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp) for searching business licenses, but the only problem is you have to check a box in order to get in.
#
# 1. Try to visit [the public search page](https://jportal.mdcourts.gov/license/pbPublicSearch.jsp)
# 2. Get redirected to a "I agree to this" page. Click that you've read the disclaimer, click Enter the Site.
# 3. Click "Search License Records" down at the bottom of the page
# 4. You're now on the search page! From the "Jurisdiction" dropdown, select "Statewide"
# 5. In the "Trade Name" field, type "Vap%" to try to find vape shops
# 6. Click "Next" in the bottom right-hand corner to go to the next page
# 7. Click "Click for detail" to see the details for a specific business license.
#
# That's a lot of stuff! **Let's get to work.**

# %% [markdown]
# ## Preparation
#
# ### When you search for a business license, what URL should Selenium try to visit first?

# %%
# https://jportal.mdcourts.gov/license/pbPublicSearch.jsp

# %% [markdown]
# **It isn't going to work, though! It's going to redirect to that intro page.** You can use *Incognito mode* to go back through the "Check the box, etc" series of pages.
#
# ### How will you identify the checkbox to check it?
#
# Selenium can find elements by:
#
# - name
# - Class
# - ID
# - CSS selector (**ASK ME WHAT THIS IS** if you don't know)
# - XPath (**ASK ME WHAT THIS IS** because you definitely don't know)
# - Link text
# - Partial link text
#
# So in other words, what's unique about this element?
#
# - *TIP: I have a secret awesome way to do this, but you have to ask.*

# %%
#XPath <3

# %% [markdown]
# ### How will you identify the button to select it, or the form to submit it?
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get('https://jportal.mdcourts.gov/license/pbPublicSearch.jsp')

# %%
check_box = driver.find_element_by_id("checkbox")
check_box.click()

# %%
enter_site = driver.find_element_by_xpath('/html/body/table/tbody/tr[7]/td/form/div/input[2]')
enter_site.click()

# %% [markdown]
# ### Once you're on the next page, how will you click the "SEARCH LICENSE RECORDS" link or follow its URL?

# %%
licence_records = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[6]/td[2]/a[2]')
licence_records.click()

# %% [markdown]
# ### Now you're on the form page. How do you pick "Statewide" for the jurisdiction dropdown?

# %%
jurisdiction_dropdown = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]')
jurisdiction_dropdown.click()

statewide = driver.find_element_by_xpath('//*[@id="slcJurisdiction"]/option[2]')
statewide.click()

# %% [markdown]
# ### How do you type "vap%" into the Trade Name field?

# %%
trade_name = driver.find_element_by_xpath('//*[@id="txtTradeName"]')
trade_name.send_keys('vap%')

# %% [markdown]
# ### How do you click the submit button or submit the form?

# %%
search_form = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/form')
search_form.submit()

# %% [markdown]
# ### How can you find and click the 'Next' button on the search results page?

# %%
next_button = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
next_button.click()

# %% [markdown]
# # Okay, let's scrape!
#
# ### Use Selenium to search for vape shops statewide, and then click through until it reaches the last page.
#
# Don't scrape yet!

# %%
#elements doesn't throw an error if it doesn't exist
for page in range(1,8):
    next_buttons = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
    if len(next_buttons) > 0:
        next_buttons[0].click()
        
        
# for page in range(1,8):
#     # Try to do something, if it fails, don't throw an error
#     try:
#         next_button = driver.find_element_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
#         next_button.click()
#     except:
#         pass

# %% [markdown]
# ### Use Selenium to scrape the first page of search results for vape shops statewide (well, we'll try).
#
# - *TIP: You can find elements/text using Selenium, or use BeautifulSoup with `doc = BeautifulSoup(driver.page_source)`*
#
# I've included some BeautifulSoup code that might be helpful. If you use it, **ask me how I made it.** It's important.

# %%
for page in range(1,8):
    next_buttons = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[1]/a')
    if len(next_buttons) > 0:
        next_buttons[0].click()

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

doc = BeautifulSoup(driver.page_source, 'html.parser')
doc
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="EN" xmlns="http://www.w3.org/1999/xhtml"><head>
# <title>Maryland Judiciary Business Licenses Online</title>
# <link href="theme/styles.css" rel="STYLESHEET" type="text/css"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# </head>
# <body>
# <!-- HEADER AREA - Header graphic, company logo and link images go here-->
# <table border="0" cellpadding="0" cellspacing="0" summary="Page Layout Table" width="100%">
# <tbody><tr>
# <td colspan="3">
# <img alt="MARYLAND BUSINESS LICENSES ONLINE" height="66" src="images/header_new.gif" width="596"/><img alt="" src="images/spacer.gif" width="35"/>
# </td>
# </tr>
# <tr>
# <td class="headerline">
# <img alt="blank spacer" height="18" src="images/spacer.gif" width="35"/>
# </td>
# <td align="LEFT" class="headerline">
# <table border="0" cellpadding="0" cellspacing="0" summary="Navigation Menu">
# <tbody><tr valign="top">
# <td>
# <img alt="" height="18" src="images/nav-leftedgebar.gif" width="30"/>
# </td>
# <td>
# <a href="pbIndex.jsp"><img alt="HOME" height="18" src="images/nav-home.gif" width="54"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbPublicSearch.jsp?newSearch=true">
# <img alt="SEARCH" height="18" src="images/nav-search.gif" width="153"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbDecisionTreeSteps.jsp"><img alt="NEW LICENSE" height="18" src="images/nav-newlicense.gif" width="88"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbApplyRenewLicense.jsp"><img alt="EDIT/RENEW LICENSE" height="18" src="images/nav-editrenewlicense.gif" width="133"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbPaymentHome.jsp"><img alt="MAKE A PAYMENT" height="18" src="images/nav-makepayment.gif" width="111"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbLinks.jsp"><img alt="LINKS" height="18" src="images/nav-links.gif" width="51"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbContactList.jsp"><img alt="CONTACT US" height="18" src="images/nav-contact.gif" width="85"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <a href="pbHelp.jsp"><img alt="HELP" height="18" src="images/nav-help.gif" width="37"/></a><img alt="" height="18" src="images/spacer-red_header.gif" width="1"/>
# </td>
# <td>
# <img alt="EDGE" height="18" src="images/navrightedgebar.gif" width="30"/>
# </td>
# </tr>
# </tbody></table>
# </td>
# <td class="headerline">
# <img alt="" height="18" src="images/spacer.gif"/>
# </td>
# </tr>
# </tbody></table>
# <!-- END HEADER AREA -->
# <table border="0" cellpadding="0" cellspacing="0" summary="Page Footer Area" width="100%">
# <tbody><tr valign="TOP">
# <td><img alt="" height="10" src="images/spacer.gif" width="105"/></td>
# <td><img alt="" height="10" src="images/spacer.gif"/></td>
# <td><img alt="" height="10" src="images/spacer.gif" width="100"/></td>
# <td><img alt="" height="10" src="images/spacer.gif" width="180"/></td>
# <td><img alt="" height="10" src="images/spacer.gif" width="100"/></td>
# </tr>
# <!-- DIRECTORY - This area is designated for the location of the current page being viewed so the enduser can easily determine his/her location within this website-->
# <tr>
# <td><img alt="" height="1" src="images/spacer.gif" width="105"/></td>
# <td class="copy" colspan="4"><a href="pbIndex.jsp">HOME</a> &gt; <a href="pbPublicSearch.jsp?newSearch=true">Search License</a> &gt; Search Results</td>
# </tr>
# <!-- END DIRECTORY LINE -->
# <tr valign="top">
# <td colspan="5"><img alt="" height="25" src="images/spacer.gif"/></td>
# </tr>
# <!-- CONTENT AREA - This is the main section that contains all the main information for this page -->
# <tr valign="top">
# <td><img alt="" src="images/spacer.gif" width="105"/></td>
# <td>
# <!-- HEADLINE -->
# <div class="headline">Search License Results</div>
# <!-- GREETING OR INSTRUCTION - The following section contains either a greeting or direction/information of items on this page -->
# <div class="copy">Below you will find the results to your License Search.<p>
# </p><p>Not all businesses require a license issued by the Clerk of the Circuit Court.  Not all licenses are required in all counties.  The information provided is a representation of the records in the Clerk of the Circuit Court's office and is not guaranteed to be complete.  If you have questions concerning licensing please contact the Clerk of the Circuit Court's office in the county in which the business is located.  If you wish to report a business that you believe is operating without a license please contact the Comptroller of the Treasury - Business License Enforcement Division at 410-260-6240.</p>
# 				You searched for<br/>
# 				    <span class="copybold">Trade Name</span> vap%<br/>
#
#
# 				    <span class="copybold">Jurisdiction</span>
#                                 Statewide<br/>
# 				    <span class="copybold">Year</span> 2017<br/>
# <!-- CONTENT AREA -->
# <p>Displaying <span class="copybold">1-5</span> (of 32) matching your criteria</p><p></p></div>
# <div class="copybold">You may wish to reduce your search criteria to increase the number of responses found</div>
# <p>
# </p><table summary="Search Results Table">
# <tbody><tr><td colspan="3"><img alt="" height="16" src="images/spacer.gif" width="482"/></td></tr>
# <tr><td class="searchlistred" colspan="3">* Note : Detailed License Information is not available for Licenses which show a status of Pending</td></tr>
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">1.</td>
# <td class="searchlistitem"><span class="copybold">VAPE IT STORE II</span></td>
# <td><a href="pbLicenseDetail.jsp?owi=lSlY%2FYw0Bwk%3D"><img alt="Click for Detail of VAPE IT STORE II" src="images/link_click-detail.gif"/></a></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>AMIN NARGIS</td>
# <td><span class="copybold">Lic. Status:</span> Issued</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>1015 S SALISBURY BLVD</td>
# <td><span class="copybold">License:</span> 22173808</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>SALISBURY, MD 21801</td>
# <td><span class="copybold">Issued Date:</span> 4/27/2017</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>Wicomico County</td>
# <td></td>
# </tr>
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">2.</td>
# <td class="searchlistitem"><span class="copybold">VAPE IT STORE I</span></td>
# <td><a href="pbLicenseDetail.jsp?owi=03DkF%2FArLqY%3D"><img alt="Click for Detail of VAPE IT STORE I" src="images/link_click-detail.gif"/></a></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>AMIN NARGIS</td>
# <td><span class="copybold">Lic. Status:</span> Issued</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>1724 N SALISBURY BLVD UNIT 2</td>
# <td><span class="copybold">License:</span> 22173807</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>SALISBURY, MD 21801</td>
# <td><span class="copybold">Issued Date:</span> 4/27/2017</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>Wicomico County</td>
# <td></td>
# </tr>
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">3.</td>
# <td class="searchlistitem"><span class="copybold">VAPEPAD THE</span></td>
# <td><a href="pbLicenseDetail.jsp?owi=A752hmdEHwU%3D"><img alt="Click for Detail of VAPEPAD THE" src="images/link_click-detail.gif"/></a></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>ANJ DISTRIBUTIONS LLC</td>
# <td><span class="copybold">Lic. Status:</span> Issued</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>2299 JOHNS HOPKINS ROAD</td>
# <td><span class="copybold">License:</span> 02104436</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>GAMBRILLS, MD 21054</td>
# <td><span class="copybold">Issued Date:</span> 4/05/2017</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>Anne Arundel County</td>
# <td></td>
# </tr>
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">4.</td>
# <td class="searchlistitem"><span class="copybold">VAPE FROG</span></td>
# <td><a href="pbLicenseDetail.jsp?owi=XO5OlMV2i1Y%3D"><img alt="Click for Detail of VAPE FROG" src="images/link_click-detail.gif"/></a></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>COX TRADING COMPANY L L C</td>
# <td><span class="copybold">Lic. Status:</span> Issued</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>110 S. PINEY RD</td>
# <td><span class="copybold">License:</span> 17165957</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>CHESTER, MD 21619</td>
# <td><span class="copybold">Issued Date:</span> 5/31/2017</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>Queen Anne's County</td>
# <td></td>
# </tr>
# <tr class="searchfieldtitle">
# <td class="searchlistnumber">5.</td>
# <td class="searchlistitem"><span class="copybold">VAPE FROG</span></td>
# <td>Pending <span class="searchlistred">*</span></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>COX TRADING LLC</td>
# <td><span class="copybold">Lic. Status:</span> Pending</td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>346 RITCHIE HIGHWAY</td>
# <td></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>SEVERNA PARK, MD 21146</td>
# <td></td>
# </tr>
# <tr class="tablecelltext">
# <td> </td>
# <td>Anne Arundel County</td>
# <td></td>
# </tr>
# </tbody></table>
# <table class="btmnavtable" summary="Bottom Navigation">
# <tbody><tr>
# <td align="left"></td>
# <td align="center" class="tablecelltext">Page:
#
#                                     <span class="copybold">1</span>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=5">2</a>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=10">3</a>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=15">4</a>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=20">5</a>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=25">6</a>
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=30">7</a>
# </td>
# <td align="right">
# <a href="/license/pbSearchResult.jsp?slcJurisdiction=50&amp;txtTradeName=vap%25&amp;txtOwnerName=&amp;txtLocationStreetName=&amp;slcYear=2017&amp;slcSortBy=ownername&amp;pager.offset=5"><nobr>Next »</nobr></a>
# </td>
# </tr>
# </tbody></table>
# <!-- END CONTENT AREA -->
# </td>
# <td><img alt="" src="images/spacer.gif" width="100"/></td>
# <td>
# <!-- DYNAMIC GOLD BOX - This message box appears on all pages and contains up-to-date information, FAQ, important updates or key point on the current page -->
# <table class="copy" summary="Helpful Information Area">
# <tbody><tr>
# <td>
# <div class="bl">
# <div class="br">
# <div class="tl">
# <div class="tr">
# <div class="boxintroheader">Get the right license</div><br/>
# <div class="boxheadline">"How do I get started?"</div><br/>
# <div class="hrline"><img alt="." src="images/spacer-red.gif"/></div><br/>
# <div class="copy"><a href="pbStartabusiness.jsp">Starting a new business in Maryland?</a><img alt="" height="1" src="images/spacer.gif"/></div><br/>
# <div class="copy"><a href="pbFaq.jsp">FAQ-Frequently Asked Questions</a><img alt="" height="1" src="images/spacer.gif"/></div><br/>
# <div class="copy"><a href="pbLaw.jsp">MD Law Title 17</a><img alt="" height="1" src="images/spacer.gif"/></div><br/>
# <div class="copy"><a href="pbContactList.jsp">View contact information for all Clerks of the Circuit Court</a><img alt="" height="1" src="images/spacer.gif"/></div><br/>
# <div class="hrline"><img alt="." src="images/spacer-red.gif"/></div><br/>
# <div class="boxheadline">Helpful Hints</div><br/>
# <div class="copybold">Use the "click for detail" link to see the Business License information</div><br/>
# <div class="hrline"><img alt="." src="images/spacer-red.gif"/></div><br/>
# <div class="copybold">If you want to add or edit/renew a license,<br/><a href="pbLogin.jsp"><div class="">PLEASE LOGIN HERE.</div></a></div><img alt="" height="1" src="images/spacer.gif"/></div><br/>
# </div>
# </div>
# </div>
# <div class="clear"> </div>
# </td>
# </tr>
# <!--What's New text-->
# <!--End What's New text-->
# </tbody></table>
# <!-- END DYNAMIC BOX -->
# </td>
# <td><img alt="" src="images/spacer.gif"/></td>
# </tr>
# <tr>
# <td colspan="5"><img alt="" height="25" src="images/spacer.gif" width="100"/></td>
# </tr>
# <!-- FOOTER NAVIGATION - This area contains all navigation links found in header area in text format -->
# <tr>
# <td><img alt="" height="1" src="images/spacer.gif" width="100"/></td>
# <td class="divider" colspan="4">
# <a href="pbIndex.jsp">HOME</a> |
#             <a href="pbPublicSearch.jsp?newSearch=true">SEARCH LICENSE RECORDS</a> |
#             <a href="pbDecisionTreeSteps.jsp">NEW LICENSE</a> |
#             <a href="pbApplyRenewLicense.jsp">EDIT/RENEW LICENSES</a> |
#             <a href="pbPaymentHome.jsp">MAKE A PAYMENT</a> |
#             <a href="pbLinks.jsp">LINKS</a> |
#             <a href="pbContactList.jsp">CONTACT US</a> |
#             <a href="pbHelp.jsp">HELP</a>
# </td>
# </tr>
# <!-- DISCLAIMER-->
# <tr>
# <td colspan="5"><img alt="" height="25" src="images/spacer.gif" width="100"/></td>
# </tr>
# <tr>
# <td><img alt="" height="1" src="images/spacer.gif" width="100"/></td>
# <td class="legaldisclaimer" colspan="3">The Maryland Judiciary, its agencies, officers, or employees do not guarantee the accuracy, reliability or
#         timeliness of any information contained in this system.  Users rely on this information at their own risk.</td>
# <td></td>
# </tr>
# <!-- END DISCLAIMER-->
# <!-- END FOOTER NAVIGATION -->
# </tbody></table>
# </body></html>

# %%
# IF YOU ARE USING BEAUTIFULSOUP, HERE IS SOME SAMPLE CODE
# IF YOU USE THIS CODE, ASK ME HOW I MADE IT. IT'S IMPORTANT.
business_headers = doc.find_all('tr',class_='searchfieldtitle')
len(business_headers)
# Out:
# 5

# %%
# You'll probably need to find specific tds inside
# of the rows instead of looking at the whole thing.

stores = []

for header in business_headers:
    Vape_Stores = {}
    rows = header.find_next_siblings('tr')
    print("HEADER is", header.text.strip())
    link = header.find('a')
    if link:
        link_2 = header.find('a')['href']
        print("Click for detail", "https://jportal.mdcourts.gov/license/" + link_2)
        Vape_Stores['Details'] = "https://jportal.mdcourts.gov/license/" + link_2
    print("ROW 0 IS", rows[0].text.strip())
    print("ROW 1 IS", rows[1].text.strip())
    print("ROW 2 IS", rows[2].text.strip())
    print("ROW 3 IS", rows[3].text.strip())
    Vape_Stores['Store'] = header.find_all('td')[1].text.strip()
    Vape_Stores['Company'] = rows[0].find_all('td')[1].text.strip()
    Vape_Stores['Address'] = rows[1].find_all('td')[1].text.strip() + rows[2].find_all('td')[1].text.strip()
    Vape_Stores['County'] = rows[3].find_all('td')[1].text.strip()
    Vape_Stores['Lic. Status'] = rows[0].find_all('td')[2].text.strip().replace('Lic. Status: ', '')
    Vape_Stores['License'] = rows[1].find_all('td')[2].text.strip().replace('License: ', '')
    Vape_Stores['Issued Date'] = rows[2].find_all('td')[2].text.strip().replace('Issued Date: ', '')
    stores.append(Vape_Stores)
    print(Vape_Stores)
    print("----")
# Out:
# HEADER is 1.
# VAPE IT STORE II
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=lSlY%2FYw0Bwk%3D
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1015 S SALISBURY BLVD
# License: 22173808
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=lSlY%2FYw0Bwk%3D', 'Store': 'VAPE IT STORE II', 'Company': 'AMIN NARGIS', 'Address': '1015 S SALISBURY BLVDSALISBURY, MD 21801', 'County': 'Wicomico County', 'Lic. Status': 'Issued', 'License': '22173808', 'Issued Date': '4/27/2017'}
# ----
# HEADER is 2.
# VAPE IT STORE I
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=03DkF%2FArLqY%3D
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1724 N SALISBURY BLVD UNIT 2
# License: 22173807
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=03DkF%2FArLqY%3D', 'Store': 'VAPE IT STORE I', 'Company': 'AMIN NARGIS', 'Address': '1724 N SALISBURY BLVD UNIT 2SALISBURY, MD 21801', 'County': 'Wicomico County', 'Lic. Status': 'Issued', 'License': '22173807', 'Issued Date': '4/27/2017'}
# ----
# HEADER is 3.
# VAPEPAD THE
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=A752hmdEHwU%3D
# ROW 0 IS ANJ DISTRIBUTIONS LLC
# Lic. Status: Issued
# ROW 1 IS 2299 JOHNS HOPKINS ROAD
# License: 02104436
# ROW 2 IS GAMBRILLS, MD 21054
# Issued Date: 4/05/2017
# ROW 3 IS Anne Arundel County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=A752hmdEHwU%3D', 'Store': 'VAPEPAD THE', 'Company': 'ANJ DISTRIBUTIONS LLC', 'Address': '2299 JOHNS HOPKINS ROADGAMBRILLS, MD 21054', 'County': 'Anne Arundel County', 'Lic. Status': 'Issued', 'License': '02104436', 'Issued Date': '4/05/2017'}
# ----
# HEADER is 4.
# VAPE FROG
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XO5OlMV2i1Y%3D
# ROW 0 IS COX TRADING COMPANY L L C
# Lic. Status: Issued
# ROW 1 IS 110 S. PINEY RD
# License: 17165957
# ROW 2 IS CHESTER, MD 21619
# Issued Date: 5/31/2017
# ROW 3 IS Queen Anne's County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XO5OlMV2i1Y%3D', 'Store': 'VAPE FROG', 'Company': 'COX TRADING COMPANY L L C', 'Address': '110 S. PINEY RDCHESTER, MD 21619', 'County': "Queen Anne's County", 'Lic. Status': 'Issued', 'License': '17165957', 'Issued Date': '5/31/2017'}
# ----
# HEADER is 5.
# VAPE FROG
# Pending *
# ROW 0 IS COX TRADING LLC
# Lic. Status: Pending
# ROW 1 IS 346 RITCHIE HIGHWAY
# ROW 2 IS SEVERNA PARK, MD 21146
# ROW 3 IS Anne Arundel County
# {'Store': 'VAPE FROG', 'Company': 'COX TRADING LLC', 'Address': '346 RITCHIE HIGHWAYSEVERNA PARK, MD 21146', 'County': 'Anne Arundel County', 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----

# %% [markdown]
# ### Save these into `vape-results.csv`

# %%
import pandas as pd

# %%
df = pd.DataFrame(stores)
df.head()
# Out:
#                                            Address                    Company  \
# 0         1015 S SALISBURY BLVDSALISBURY, MD 21801                AMIN NARGIS
# 1  1724 N SALISBURY BLVD UNIT 2SALISBURY, MD 21801                AMIN NARGIS
# 2       2299 JOHNS HOPKINS ROADGAMBRILLS, MD 21054      ANJ DISTRIBUTIONS LLC
# 3                 110 S. PINEY RDCHESTER, MD 21619  COX TRADING COMPANY L L C
# 4        346 RITCHIE HIGHWAYSEVERNA PARK, MD 21146            COX TRADING LLC
#
#                 County                                            Details  \
# 0      Wicomico County  https://jportal.mdcourts.gov/license/pbLicense...
# 1      Wicomico County  https://jportal.mdcourts.gov/license/pbLicense...
# 2  Anne Arundel County  https://jportal.mdcourts.gov/license/pbLicense...
# 3  Queen Anne's County  https://jportal.mdcourts.gov/license/pbLicense...
# 4  Anne Arundel County                                                NaN
#
#   Issued Date Lic. Status   License             Store
# 0   4/27/2017      Issued  22173808  VAPE IT STORE II
# 1   4/27/2017      Issued  22173807   VAPE IT STORE I
# 2   4/05/2017      Issued  02104436       VAPEPAD THE
# 3   5/31/2017      Issued  17165957         VAPE FROG
# 4                 Pending                   VAPE FROG

# %%
df.to_csv("vape_results.csv", index=False)

# %% [markdown]
# ### Open `vape-results.csv` to make sure there aren't any extra weird columns

# %%
vape_results_df = pd.read_csv("vape_results.csv")
vape_results_df
# Out:
#                                            Address                    Company  \
# 0         1015 S SALISBURY BLVDSALISBURY, MD 21801                AMIN NARGIS
# 1  1724 N SALISBURY BLVD UNIT 2SALISBURY, MD 21801                AMIN NARGIS
# 2       2299 JOHNS HOPKINS ROADGAMBRILLS, MD 21054      ANJ DISTRIBUTIONS LLC
# 3                 110 S. PINEY RDCHESTER, MD 21619  COX TRADING COMPANY L L C
# 4        346 RITCHIE HIGHWAYSEVERNA PARK, MD 21146            COX TRADING LLC
#
#                 County                                            Details  \
# 0      Wicomico County  https://jportal.mdcourts.gov/license/pbLicense...
# 1      Wicomico County  https://jportal.mdcourts.gov/license/pbLicense...
# 2  Anne Arundel County  https://jportal.mdcourts.gov/license/pbLicense...
# 3  Queen Anne's County  https://jportal.mdcourts.gov/license/pbLicense...
# 4  Anne Arundel County                                                NaN
#
#   Issued Date Lic. Status     License             Store
# 0   4/27/2017      Issued  22173808.0  VAPE IT STORE II
# 1   4/27/2017      Issued  22173807.0   VAPE IT STORE I
# 2   4/05/2017      Issued   2104436.0       VAPEPAD THE
# 3   5/31/2017      Issued  17165957.0         VAPE FROG
# 4         NaN     Pending         NaN         VAPE FROG

# %% [markdown]
# ## Use Selenium to scrape ALL pages of results, save the results into `vape-results-all.csv`.

# %%
stores_all = []

for page in range(1,8):
    doc = BeautifulSoup(driver.page_source, 'html.parser')
    business_headers = doc.find_all('tr',class_='searchfieldtitle')
    for header in business_headers:
        Vape_Stores_all = {}
        rows = header.find_next_siblings('tr')
        print("HEADER is", header.text.strip())
        link = header.find('a')
        if link:
            link_2 = header.find('a')['href']
            print("Click for detail", "https://jportal.mdcourts.gov/license/" + link_2)
            Vape_Stores_all['Details'] = "https://jportal.mdcourts.gov/license/" + link_2
        print("ROW 0 IS", rows[0].text.strip())
        print("ROW 1 IS", rows[1].text.strip())
        print("ROW 2 IS", rows[2].text.strip())
        print("ROW 3 IS", rows[3].text.strip())
        Vape_Stores_all['Store'] = header.find_all('td')[1].text.strip()
        Vape_Stores_all['Company'] = rows[0].find_all('td')[1].text.strip()
        Vape_Stores_all['Address'] = rows[1].find_all('td')[1].text.strip() + rows[2].find_all('td')[1].text.strip()
        Vape_Stores_all['County'] = rows[3].find_all('td')[1].text.strip()
        Vape_Stores_all['Lic. Status'] = rows[0].find_all('td')[2].text.strip().replace('Lic. Status: ', '')
        Vape_Stores_all['License'] = rows[1].find_all('td')[2].text.strip().replace('License: ', '')
        Vape_Stores_all['Issued Date'] = rows[2].find_all('td')[2].text.strip().replace('Issued Date: ', '')
        stores_all.append(Vape_Stores_all)
        print(Vape_Stores_all)
        print("----")
    next_buttons = driver.find_elements_by_xpath('/html/body/table[2]/tbody/tr[4]/td[2]/table[2]/tbody/tr/td[3]/a/nobr')
    if len(next_buttons) > 0:
        next_buttons[0].click()
# Out:
# HEADER is 1.
# VAPE IT STORE II
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=lSlY%2FYw0Bwk%3D
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1015 S SALISBURY BLVD
# License: 22173808
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=lSlY%2FYw0Bwk%3D', 'Store': 'VAPE IT STORE II', 'Company': 'AMIN NARGIS', 'Address': '1015 S SALISBURY BLVDSALISBURY, MD 21801', 'County': 'Wicomico County', 'Lic. Status': 'Issued', 'License': '22173808', 'Issued Date': '4/27/2017'}
# ----
# HEADER is 2.
# VAPE IT STORE I
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=03DkF%2FArLqY%3D
# ROW 0 IS AMIN NARGIS
# Lic. Status: Issued
# ROW 1 IS 1724 N SALISBURY BLVD UNIT 2
# License: 22173807
# ROW 2 IS SALISBURY, MD 21801
# Issued Date: 4/27/2017
# ROW 3 IS Wicomico County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=03DkF%2FArLqY%3D', 'Store': 'VAPE IT STORE I', 'Company': 'AMIN NARGIS', 'Address': '1724 N SALISBURY BLVD UNIT 2SALISBURY, MD 21801', 'County': 'Wicomico County', 'Lic. Status': 'Issued', 'License': '22173807', 'Issued Date': '4/27/2017'}
# ----
# HEADER is 3.
# VAPEPAD THE
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=A752hmdEHwU%3D
# ROW 0 IS ANJ DISTRIBUTIONS LLC
# Lic. Status: Issued
# ROW 1 IS 2299 JOHNS HOPKINS ROAD
# License: 02104436
# ROW 2 IS GAMBRILLS, MD 21054
# Issued Date: 4/05/2017
# ROW 3 IS Anne Arundel County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=A752hmdEHwU%3D', 'Store': 'VAPEPAD THE', 'Company': 'ANJ DISTRIBUTIONS LLC', 'Address': '2299 JOHNS HOPKINS ROADGAMBRILLS, MD 21054', 'County': 'Anne Arundel County', 'Lic. Status': 'Issued', 'License': '02104436', 'Issued Date': '4/05/2017'}
# ----
# HEADER is 4.
# VAPE FROG
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XO5OlMV2i1Y%3D
# ROW 0 IS COX TRADING COMPANY L L C
# Lic. Status: Issued
# ROW 1 IS 110 S. PINEY RD
# License: 17165957
# ROW 2 IS CHESTER, MD 21619
# Issued Date: 5/31/2017
# ROW 3 IS Queen Anne's County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=XO5OlMV2i1Y%3D', 'Store': 'VAPE FROG', 'Company': 'COX TRADING COMPANY L L C', 'Address': '110 S. PINEY RDCHESTER, MD 21619', 'County': "Queen Anne's County", 'Lic. Status': 'Issued', 'License': '17165957', 'Issued Date': '5/31/2017'}
# ----
# HEADER is 5.
# VAPE FROG
# Pending *
# ROW 0 IS COX TRADING LLC
# Lic. Status: Pending
# ROW 1 IS 346 RITCHIE HIGHWAY
# ROW 2 IS SEVERNA PARK, MD 21146
# ROW 3 IS Anne Arundel County
# {'Store': 'VAPE FROG', 'Company': 'COX TRADING LLC', 'Address': '346 RITCHIE HIGHWAYSEVERNA PARK, MD 21146', 'County': 'Anne Arundel County', 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 6.
# VAPE LOFT (THE)
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZbTW0VmFa1Y%3D
# ROW 0 IS DISBROW II EMERSON HARRINGTON
# Lic. Status: Issued
# ROW 1 IS 185 MITCHELLS CHANCE RD
# License: 02102408
# ROW 2 IS EDGEWATER, MD 21037
# Issued Date: 4/13/2017
# ROW 3 IS Anne Arundel County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZbTW0VmFa1Y%3D', 'Store': 'VAPE LOFT (THE)', 'Company': 'DISBROW II EMERSON HARRINGTON', 'Address': '185 MITCHELLS CHANCE RDEDGEWATER, MD 21037', 'County': 'Anne Arundel County', 'Lic. Status': 'Issued', 'License': '02102408', 'Issued Date': '4/13/2017'}
# ----
# HEADER is 7.
# VAPE N CIGAR
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=fFWYeon3ykY%3D
# ROW 0 IS DISCOUNT TOBACCO ESSEX LLC
# Lic. Status: Issued
# ROW 1 IS 7104 MINSTREL UNIT #7
# License: 13141786
# ROW 2 IS COLUMBIA, MD 21045
# Issued Date: 5/19/2017
# ROW 3 IS Howard County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=fFWYeon3ykY%3D', 'Store': 'VAPE N CIGAR', 'Company': 'DISCOUNT TOBACCO ESSEX LLC', 'Address': '7104 MINSTREL UNIT #7COLUMBIA, MD 21045', 'County': 'Howard County', 'Lic. Status': 'Issued', 'License': '13141786', 'Issued Date': '5/19/2017'}
# ----
# HEADER is 8.
# VAPE DOJO
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=NbUYcXEGef0%3D
# ROW 0 IS FAIRGROUND VILLAGE LLC
# Lic. Status: Issued
# ROW 1 IS 330 ONE FORTY VILLAGE ROAD
# License: 06126253
# ROW 2 IS WESTMINSTER, MD 21157
# Issued Date: 4/21/2017
# ROW 3 IS Carroll County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=NbUYcXEGef0%3D', 'Store': 'VAPE DOJO', 'Company': 'FAIRGROUND VILLAGE LLC', 'Address': '330 ONE FORTY VILLAGE ROADWESTMINSTER, MD 21157', 'County': 'Carroll County', 'Lic. Status': 'Issued', 'License': '06126253', 'Issued Date': '4/21/2017'}
# ----
# HEADER is 9.
# VAPE HAVEN
# Pending *
# ROW 0 IS GRIMM JENNIFER
# Lic. Status: Pending
# ROW 1 IS 29890 THREE NOTCH ROAD
# ROW 2 IS CHARLOTTE HALL, MD 20622
# ROW 3 IS St. Mary's County
# {'Store': 'VAPE HAVEN', 'Company': 'GRIMM JENNIFER', 'Address': '29890 THREE NOTCH ROADCHARLOTTE HALL, MD 20622', 'County': "St. Mary's County", 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 10.
# VAPE BIRD
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=QBXvhzsxClg%3D
# ROW 0 IS HUTCH VAPES LLC
# Lic. Status: Issued
# ROW 1 IS 356 ROMANCOKE ROAD
# License: 17166688
# ROW 2 IS STEVENSVILLE, MD 21666
# Issued Date: 4/13/2017
# ROW 3 IS Queen Anne's County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=QBXvhzsxClg%3D', 'Store': 'VAPE BIRD', 'Company': 'HUTCH VAPES LLC', 'Address': '356 ROMANCOKE ROADSTEVENSVILLE, MD 21666', 'County': "Queen Anne's County", 'Lic. Status': 'Issued', 'License': '17166688', 'Issued Date': '4/13/2017'}
# ----
# HEADER is 11.
# VAPE FROG
# Pending *
# ROW 0 IS HUTCHINS COX LLP
# Lic. Status: Pending
# ROW 1 IS 110 S PINEY ROAD  STE 106
# ROW 2 IS CHESTER, MD 21619
# ROW 3 IS Queen Anne's County
# {'Store': 'VAPE FROG', 'Company': 'HUTCHINS COX LLP', 'Address': '110 S PINEY ROAD  STE 106CHESTER, MD 21619', 'County': "Queen Anne's County", 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 12.
# VAPORS LOUNGE
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=LXLjsj25M2g%3D
# ROW 0 IS JAMESON WILLIAM
# Lic. Status: Issued
# ROW 1 IS 28943 THREE NOTCH ROAD
# License: 18167503
# ROW 2 IS MECHANICSVILLE, MD 20659
# Issued Date: 5/17/2017
# ROW 3 IS St. Mary's County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=LXLjsj25M2g%3D', 'Store': 'VAPORS LOUNGE', 'Company': 'JAMESON WILLIAM', 'Address': '28943 THREE NOTCH ROADMECHANICSVILLE, MD 20659', 'County': "St. Mary's County", 'Lic. Status': 'Issued', 'License': '18167503', 'Issued Date': '5/17/2017'}
# ----
# HEADER is 13.
# VAPORS LOUNGE
# Pending *
# ROW 0 IS JAMESON WILLIAM E
# Lic. Status: Pending
# ROW 1 IS 6843 CRAIN HIGHWAY
# ROW 2 IS LA PLATA, MD 20646
# ROW 3 IS Charles County
# {'Store': 'VAPORS LOUNGE', 'Company': 'JAMESON WILLIAM E', 'Address': '6843 CRAIN HIGHWAYLA PLATA, MD 20646', 'County': 'Charles County', 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 14.
# VAPIST MD
# Pending *
# ROW 0 IS JEFFERS MICHAEL
# Lic. Status: Pending
# ROW 1 IS 6321 OLD BRANCH AVE
# ROW 2 IS CAMP SPRINGS, MD 20748
# ROW 3 IS St. Mary's County
# {'Store': 'VAPIST MD', 'Company': 'JEFFERS MICHAEL', 'Address': '6321 OLD BRANCH AVECAMP SPRINGS, MD 20748', 'County': "St. Mary's County", 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 15.
# VAPIST MD LLC
# Pending *
# ROW 0 IS JEFFERS MICHAEL W
# Lic. Status: Pending
# ROW 1 IS 6321 OLD BRANCH AVE
# ROW 2 IS CAMP SPRINGS, MD 20748
# ROW 3 IS Prince George's County
# {'Store': 'VAPIST MD LLC', 'Company': 'JEFFERS MICHAEL W', 'Address': '6321 OLD BRANCH AVECAMP SPRINGS, MD 20748', 'County': "Prince George's County", 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 16.
# VAPERTETMD
# Pending *
# ROW 0 IS SHIN JENNY Y
# Lic. Status: Pending
# ROW 1 IS 7954 B AND A BLVD
# ROW 2 IS GLEN BURNIE, MD 21060
# ROW 3 IS Anne Arundel County
# {'Store': 'VAPERTETMD', 'Company': 'SHIN JENNY Y', 'Address': '7954 B AND A BLVDGLEN BURNIE, MD 21060', 'County': 'Anne Arundel County', 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 17.
# VAPERTEKMD
# Pending *
# ROW 0 IS SHIN JENNY YOUNG
# Lic. Status: Pending
# ROW 1 IS 6325 WASHINGTON BLVD
# ROW 2 IS ELKRIDGE, MD 21075
# ROW 3 IS Howard County
# {'Store': 'VAPERTEKMD', 'Company': 'SHIN JENNY YOUNG', 'Address': '6325 WASHINGTON BLVDELKRIDGE, MD 21075', 'County': 'Howard County', 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 18.
# VAPORIOT
# Pending *
# ROW 0 IS TAYLOR TRAVIS
# Lic. Status: Pending
# ROW 1 IS 3203 NORTH POINT RD
# ROW 2 IS BALTIMORE, MD 21222
# ROW 3 IS Baltimore County
# {'Store': 'VAPORIOT', 'Company': 'TAYLOR TRAVIS', 'Address': '3203 NORTH POINT RDBALTIMORE, MD 21222', 'County': 'Baltimore County', 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 19.
# VAPE PLUS
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=O98RAdvR2fQ%3D
# ROW 0 IS TRUE ENTERPRISE INC
# Lic. Status: Issued
# ROW 1 IS 519 LINDEN AVENUE UNIT 6
# License: 23178140
# ROW 2 IS POCOMOKE CITY, MD 21851
# Issued Date: 5/05/2017
# ROW 3 IS Worcester County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=O98RAdvR2fQ%3D', 'Store': 'VAPE PLUS', 'Company': 'TRUE ENTERPRISE INC', 'Address': '519 LINDEN AVENUE UNIT 6POCOMOKE CITY, MD 21851', 'County': 'Worcester County', 'Lic. Status': 'Issued', 'License': '23178140', 'Issued Date': '5/05/2017'}
# ----
# HEADER is 20.
# VAPE  SOCIAL
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=5GRQYuFhrKE%3D
# ROW 0 IS VAPE  SOCIAL  LLC
# Lic. Status: Issued
# ROW 1 IS 16521 S FREDERICK AVE
# License: 15155429
# ROW 2 IS GAITHERSBURG, MD 20877
# Issued Date: 4/18/2017
# ROW 3 IS Montgomery County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=5GRQYuFhrKE%3D', 'Store': 'VAPE  SOCIAL', 'Company': 'VAPE  SOCIAL  LLC', 'Address': '16521 S FREDERICK AVEGAITHERSBURG, MD 20877', 'County': 'Montgomery County', 'Lic. Status': 'Issued', 'License': '15155429', 'Issued Date': '4/18/2017'}
# ----
# HEADER is 21.
# VAPE JUNGLE
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=7hlMpOr1HKw%3D
# ROW 0 IS VAPE JUNGLE LLC
# Lic. Status: Issued
# ROW 1 IS 2070 CRAIN HIGHWAY  UNIT F
# License: 08131285
# ROW 2 IS WALDORF, MD 20601
# Issued Date: 3/31/2017
# ROW 3 IS Charles County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=7hlMpOr1HKw%3D', 'Store': 'VAPE JUNGLE', 'Company': 'VAPE JUNGLE LLC', 'Address': '2070 CRAIN HIGHWAY  UNIT FWALDORF, MD 20601', 'County': 'Charles County', 'Lic. Status': 'Issued', 'License': '08131285', 'Issued Date': '3/31/2017'}
# ----
# HEADER is 22.
# VAPE TIME
# Pending *
# ROW 0 IS VAPE TIME LLC
# Lic. Status: Pending
# ROW 1 IS 4130 E JOPPA RD UNIT 109
# ROW 2 IS NOTTINGHAM, MD 21236
# ROW 3 IS Baltimore County
# {'Store': 'VAPE TIME', 'Company': 'VAPE TIME LLC', 'Address': '4130 E JOPPA RD UNIT 109NOTTINGHAM, MD 21236', 'County': 'Baltimore County', 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 23.
# VAPEBAR EXPESS
# Pending *
# ROW 0 IS VAPEBAR EXPRESS LLC
# Lic. Status: Pending
# ROW 1 IS 11110 MALL CIRCLE
# ROW 2 IS WALDORF, MD 20603
# ROW 3 IS Charles County
# {'Store': 'VAPEBAR EXPESS', 'Company': 'VAPEBAR EXPRESS LLC', 'Address': '11110 MALL CIRCLEWALDORF, MD 20603', 'County': 'Charles County', 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 24.
# VAPOR 99
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Y1obT418HAc%3D
# ROW 0 IS VAPOR 99 LLC
# Lic. Status: Issued
# ROW 1 IS 3524 CRAIN HWY
# License: 16165362
# ROW 2 IS BOWIE, MD 20716
# Issued Date: 5/03/2017
# ROW 3 IS Prince George's County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Y1obT418HAc%3D', 'Store': 'VAPOR 99', 'Company': 'VAPOR 99 LLC', 'Address': '3524 CRAIN HWYBOWIE, MD 20716', 'County': "Prince George's County", 'Lic. Status': 'Issued', 'License': '16165362', 'Issued Date': '5/03/2017'}
# ----
# HEADER is 25.
# VAPOR ALLEY
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=bk%2FCgwllrIk%3D
# ROW 0 IS VAPOR ALLEY LLC
# Lic. Status: Issued
# ROW 1 IS 8117 OCEAN GATEWAY UNIT #4
# License: 20170900
# ROW 2 IS EASTON, MD 21601
# Issued Date: 5/10/2017
# ROW 3 IS Talbot County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=bk%2FCgwllrIk%3D', 'Store': 'VAPOR ALLEY', 'Company': 'VAPOR ALLEY LLC', 'Address': '8117 OCEAN GATEWAY UNIT #4EASTON, MD 21601', 'County': 'Talbot County', 'Lic. Status': 'Issued', 'License': '20170900', 'Issued Date': '5/10/2017'}
# ----
# HEADER is 26.
# VAPOR EMPORIUM
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=b174aIMod48%3D
# ROW 0 IS VAPOR EMPORIUM MD LLC
# Lic. Status: Issued
# ROW 1 IS 11717 OLD NATIONAL PIKE
# License: 10135432
# ROW 2 IS NEW MARKET, MD 21774
# Issued Date: 4/14/2017
# ROW 3 IS Frederick County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=b174aIMod48%3D', 'Store': 'VAPOR EMPORIUM', 'Company': 'VAPOR EMPORIUM MD LLC', 'Address': '11717 OLD NATIONAL PIKENEW MARKET, MD 21774', 'County': 'Frederick County', 'Lic. Status': 'Issued', 'License': '10135432', 'Issued Date': '4/14/2017'}
# ----
# HEADER is 27.
# VAPOR VILLA
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=p%2B5FIbaM%2FoM%3D
# ROW 0 IS VAPOR VILLA CORP
# Lic. Status: Issued
# ROW 1 IS 1913 LANSDOWNE ROAD SUITE E
# License: 03121958
# ROW 2 IS BALTIMORE, MD 21227
# Issued Date: 4/12/2017
# ROW 3 IS Baltimore County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=p%2B5FIbaM%2FoM%3D', 'Store': 'VAPOR VILLA', 'Company': 'VAPOR VILLA CORP', 'Address': '1913 LANSDOWNE ROAD SUITE EBALTIMORE, MD 21227', 'County': 'Baltimore County', 'Lic. Status': 'Issued', 'License': '03121958', 'Issued Date': '4/12/2017'}
# ----
# HEADER is 28.
# VAPOR VILLA
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Zti7b%2BkNEMI%3D
# ROW 0 IS VAPOR VILLA CORP
# Lic. Status: Issued
# ROW 1 IS 730 FREDERICK ROAD
# License: 03121959
# ROW 2 IS CATONSVILLE, MD 21228
# Issued Date: 4/12/2017
# ROW 3 IS Baltimore County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=Zti7b%2BkNEMI%3D', 'Store': 'VAPOR VILLA', 'Company': 'VAPOR VILLA CORP', 'Address': '730 FREDERICK ROADCATONSVILLE, MD 21228', 'County': 'Baltimore County', 'Lic. Status': 'Issued', 'License': '03121959', 'Issued Date': '4/12/2017'}
# ----
# HEADER is 29.
# VAPE DOJO
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2BkiL1iSFMxE%3D
# ROW 0 IS WALKER TRADING CO INC
# Lic. Status: Issued
# ROW 1 IS 138 N BOND STREET
# License: 12140135
# ROW 2 IS BEL AIR, MD 21014
# Issued Date: 4/03/2017
# ROW 3 IS Harford County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=%2BkiL1iSFMxE%3D', 'Store': 'VAPE DOJO', 'Company': 'WALKER TRADING CO INC', 'Address': '138 N BOND STREETBEL AIR, MD 21014', 'County': 'Harford County', 'Lic. Status': 'Issued', 'License': '12140135', 'Issued Date': '4/03/2017'}
# ----
# HEADER is 30.
# VAPE DOJO
# Pending *
# ROW 0 IS WALKER TRADING COMPANY INC
# Lic. Status: Pending
# ROW 1 IS 11600 CROSSROAD CIR  STE E
# ROW 2 IS BALTIMORE, MD 21220
# ROW 3 IS Baltimore County
# {'Store': 'VAPE DOJO', 'Company': 'WALKER TRADING COMPANY INC', 'Address': '11600 CROSSROAD CIR  STE EBALTIMORE, MD 21220', 'County': 'Baltimore County', 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----
# HEADER is 31.
# VAPE DOJO
# Click for detail https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZGgl9G48Aa4%3D
# ROW 0 IS WALKER TRADING COMPANY INC
# Lic. Status: Issued
# ROW 1 IS 3570 SAINT JOHNS LANE, SUITE 109
# License: 13144108
# ROW 2 IS ELLICOTT CITY, MD 21042
# Issued Date: 3/27/2017
# ROW 3 IS Howard County
# {'Details': 'https://jportal.mdcourts.gov/license/pbLicenseDetail.jsp?owi=ZGgl9G48Aa4%3D', 'Store': 'VAPE DOJO', 'Company': 'WALKER TRADING COMPANY INC', 'Address': '3570 SAINT JOHNS LANE, SUITE 109ELLICOTT CITY, MD 21042', 'County': 'Howard County', 'Lic. Status': 'Issued', 'License': '13144108', 'Issued Date': '3/27/2017'}
# ----
# HEADER is 32.
# VAPEZ YARDHOUSE
# Pending *
# ROW 0 IS YARKHOUSE EMPIRE INC
# Lic. Status: Pending
# ROW 1 IS 3315 PLAZA WAY
# ROW 2 IS WALDORF, MD 20603
# ROW 3 IS Charles County
# {'Store': 'VAPEZ YARDHOUSE', 'Company': 'YARKHOUSE EMPIRE INC', 'Address': '3315 PLAZA WAYWALDORF, MD 20603', 'County': 'Charles County', 'Lic. Status': 'Pending', 'License': '', 'Issued Date': ''}
# ----

# %%
all_df = pd.DataFrame(stores_all)
all_df
# Out:
#                                               Address  \
# 0            1015 S SALISBURY BLVDSALISBURY, MD 21801
# 1     1724 N SALISBURY BLVD UNIT 2SALISBURY, MD 21801
# 2          2299 JOHNS HOPKINS ROADGAMBRILLS, MD 21054
# 3                    110 S. PINEY RDCHESTER, MD 21619
# 4           346 RITCHIE HIGHWAYSEVERNA PARK, MD 21146
# 5          185 MITCHELLS CHANCE RDEDGEWATER, MD 21037
# 6             7104 MINSTREL UNIT #7COLUMBIA, MD 21045
# 7     330 ONE FORTY VILLAGE ROADWESTMINSTER, MD 21157
# 8      29890 THREE NOTCH ROADCHARLOTTE HALL, MD 20622
# 9            356 ROMANCOKE ROADSTEVENSVILLE, MD 21666
# 10         110 S PINEY ROAD  STE 106CHESTER, MD 21619
# 11     28943 THREE NOTCH ROADMECHANICSVILLE, MD 20659
# 12               6843 CRAIN HIGHWAYLA PLATA, MD 20646
# 13          6321 OLD BRANCH AVECAMP SPRINGS, MD 20748
# 14          6321 OLD BRANCH AVECAMP SPRINGS, MD 20748
# 15             7954 B AND A BLVDGLEN BURNIE, MD 21060
# 16             6325 WASHINGTON BLVDELKRIDGE, MD 21075
# 17             3203 NORTH POINT RDBALTIMORE, MD 21222
# 18    519 LINDEN AVENUE UNIT 6POCOMOKE CITY, MD 21851
# 19        16521 S FREDERICK AVEGAITHERSBURG, MD 20877
# 20        2070 CRAIN HIGHWAY  UNIT FWALDORF, MD 20601
# 21       4130 E JOPPA RD UNIT 109NOTTINGHAM, MD 21236
# 22                 11110 MALL CIRCLEWALDORF, MD 20603
# 23                      3524 CRAIN HWYBOWIE, MD 20716
# 24         8117 OCEAN GATEWAY UNIT #4EASTON, MD 21601
# 25        11717 OLD NATIONAL PIKENEW MARKET, MD 21774
# 26     1913 LANSDOWNE ROAD SUITE EBALTIMORE, MD 21227
# 27            730 FREDERICK ROADCATONSVILLE, MD 21228
# 28                 138 N BOND STREETBEL AIR, MD 21014
# 29      11600 CROSSROAD CIR  STE EBALTIMORE, MD 21220
# 30  3570 SAINT JOHNS LANE, SUITE 109ELLICOTT CITY,...
# 31                    3315 PLAZA WAYWALDORF, MD 20603
#
#                           Company                  County  \
# 0                     AMIN NARGIS         Wicomico County
# 1                     AMIN NARGIS         Wicomico County
# 2           ANJ DISTRIBUTIONS LLC     Anne Arundel County
# 3       COX TRADING COMPANY L L C     Queen Anne's County
# 4                 COX TRADING LLC     Anne Arundel County
# 5   DISBROW II EMERSON HARRINGTON     Anne Arundel County
# 6      DISCOUNT TOBACCO ESSEX LLC           Howard County
# 7          FAIRGROUND VILLAGE LLC          Carroll County
# 8                  GRIMM JENNIFER       St. Mary's County
# 9                 HUTCH VAPES LLC     Queen Anne's County
# 10               HUTCHINS COX LLP     Queen Anne's County
# 11                JAMESON WILLIAM       St. Mary's County
# 12              JAMESON WILLIAM E          Charles County
# 13                JEFFERS MICHAEL       St. Mary's County
# 14              JEFFERS MICHAEL W  Prince George's County
# 15                   SHIN JENNY Y     Anne Arundel County
# 16               SHIN JENNY YOUNG           Howard County
# 17                  TAYLOR TRAVIS        Baltimore County
# 18            TRUE ENTERPRISE INC        Worcester County
# 19              VAPE  SOCIAL  LLC       Montgomery County
# 20                VAPE JUNGLE LLC          Charles County
# 21                  VAPE TIME LLC        Baltimore County
# 22            VAPEBAR EXPRESS LLC          Charles County
# 23                   VAPOR 99 LLC  Prince George's County
# 24                VAPOR ALLEY LLC           Talbot County
# 25          VAPOR EMPORIUM MD LLC        Frederick County
# 26               VAPOR VILLA CORP        Baltimore County
# 27               VAPOR VILLA CORP        Baltimore County
# 28          WALKER TRADING CO INC          Harford County
# 29     WALKER TRADING COMPANY INC        Baltimore County
# 30     WALKER TRADING COMPANY INC           Howard County
# 31           YARKHOUSE EMPIRE INC          Charles County
#
#                                               Details Issued Date Lic. Status  \
# 0   https://jportal.mdcourts.gov/license/pbLicense...   4/27/2017      Issued
# 1   https://jportal.mdcourts.gov/license/pbLicense...   4/27/2017      Issued
# 2   https://jportal.mdcourts.gov/license/pbLicense...   4/05/2017      Issued
# 3   https://jportal.mdcourts.gov/license/pbLicense...   5/31/2017      Issued
# 4                                                 NaN                 Pending
# 5   https://jportal.mdcourts.gov/license/pbLicense...   4/13/2017      Issued
# 6   https://jportal.mdcourts.gov/license/pbLicense...   5/19/2017      Issued
# 7   https://jportal.mdcourts.gov/license/pbLicense...   4/21/2017      Issued
# 8                                                 NaN                 Pending
# 9   https://jportal.mdcourts.gov/license/pbLicense...   4/13/2017      Issued
# 10                                                NaN                 Pending
# 11  https://jportal.mdcourts.gov/license/pbLicense...   5/17/2017      Issued
# 12                                                NaN                 Pending
# 13                                                NaN                 Pending
# 14                                                NaN                 Pending
# 15                                                NaN                 Pending
# 16                                                NaN                 Pending
# 17                                                NaN                 Pending
# 18  https://jportal.mdcourts.gov/license/pbLicense...   5/05/2017      Issued
# 19  https://jportal.mdcourts.gov/license/pbLicense...   4/18/2017      Issued
# 20  https://jportal.mdcourts.gov/license/pbLicense...   3/31/2017      Issued
# 21                                                NaN                 Pending
# 22                                                NaN                 Pending
# 23  https://jportal.mdcourts.gov/license/pbLicense...   5/03/2017      Issued
# 24  https://jportal.mdcourts.gov/license/pbLicense...   5/10/2017      Issued
# 25  https://jportal.mdcourts.gov/license/pbLicense...   4/14/2017      Issued
# 26  https://jportal.mdcourts.gov/license/pbLicense...   4/12/2017      Issued
# 27  https://jportal.mdcourts.gov/license/pbLicense...   4/12/2017      Issued
# 28  https://jportal.mdcourts.gov/license/pbLicense...   4/03/2017      Issued
# 29                                                NaN                 Pending
# 30  https://jportal.mdcourts.gov/license/pbLicense...   3/27/2017      Issued
# 31                                                NaN                 Pending
#
#      License             Store
# 0   22173808  VAPE IT STORE II
# 1   22173807   VAPE IT STORE I
# 2   02104436       VAPEPAD THE
# 3   17165957         VAPE FROG
# 4                    VAPE FROG
# 5   02102408   VAPE LOFT (THE)
# 6   13141786      VAPE N CIGAR
# 7   06126253         VAPE DOJO
# 8                   VAPE HAVEN
# 9   17166688         VAPE BIRD
# 10                   VAPE FROG
# 11  18167503     VAPORS LOUNGE
# 12               VAPORS LOUNGE
# 13                   VAPIST MD
# 14               VAPIST MD LLC
# 15                  VAPERTETMD
# 16                  VAPERTEKMD
# 17                    VAPORIOT
# 18  23178140         VAPE PLUS
# 19  15155429      VAPE  SOCIAL
# 20  08131285       VAPE JUNGLE
# 21                   VAPE TIME
# 22              VAPEBAR EXPESS
# 23  16165362          VAPOR 99
# 24  20170900       VAPOR ALLEY
# 25  10135432    VAPOR EMPORIUM
# 26  03121958       VAPOR VILLA
# 27  03121959       VAPOR VILLA
# 28  12140135         VAPE DOJO
# 29                   VAPE DOJO
# 30  13144108         VAPE DOJO
# 31             VAPEZ YARDHOUSE

# %%
all_df.to_csv("vape_results_all.csv", index=False)

# %%
vape_results_all_df = pd.read_csv("vape_results_all.csv")
vape_results_all_df
# Out:
#                                               Address  \
# 0            1015 S SALISBURY BLVDSALISBURY, MD 21801
# 1     1724 N SALISBURY BLVD UNIT 2SALISBURY, MD 21801
# 2          2299 JOHNS HOPKINS ROADGAMBRILLS, MD 21054
# 3                    110 S. PINEY RDCHESTER, MD 21619
# 4           346 RITCHIE HIGHWAYSEVERNA PARK, MD 21146
# 5          185 MITCHELLS CHANCE RDEDGEWATER, MD 21037
# 6             7104 MINSTREL UNIT #7COLUMBIA, MD 21045
# 7     330 ONE FORTY VILLAGE ROADWESTMINSTER, MD 21157
# 8      29890 THREE NOTCH ROADCHARLOTTE HALL, MD 20622
# 9            356 ROMANCOKE ROADSTEVENSVILLE, MD 21666
# 10         110 S PINEY ROAD  STE 106CHESTER, MD 21619
# 11     28943 THREE NOTCH ROADMECHANICSVILLE, MD 20659
# 12               6843 CRAIN HIGHWAYLA PLATA, MD 20646
# 13          6321 OLD BRANCH AVECAMP SPRINGS, MD 20748
# 14          6321 OLD BRANCH AVECAMP SPRINGS, MD 20748
# 15             7954 B AND A BLVDGLEN BURNIE, MD 21060
# 16             6325 WASHINGTON BLVDELKRIDGE, MD 21075
# 17             3203 NORTH POINT RDBALTIMORE, MD 21222
# 18    519 LINDEN AVENUE UNIT 6POCOMOKE CITY, MD 21851
# 19        16521 S FREDERICK AVEGAITHERSBURG, MD 20877
# 20        2070 CRAIN HIGHWAY  UNIT FWALDORF, MD 20601
# 21       4130 E JOPPA RD UNIT 109NOTTINGHAM, MD 21236
# 22                 11110 MALL CIRCLEWALDORF, MD 20603
# 23                      3524 CRAIN HWYBOWIE, MD 20716
# 24         8117 OCEAN GATEWAY UNIT #4EASTON, MD 21601
# 25        11717 OLD NATIONAL PIKENEW MARKET, MD 21774
# 26     1913 LANSDOWNE ROAD SUITE EBALTIMORE, MD 21227
# 27            730 FREDERICK ROADCATONSVILLE, MD 21228
# 28                 138 N BOND STREETBEL AIR, MD 21014
# 29      11600 CROSSROAD CIR  STE EBALTIMORE, MD 21220
# 30  3570 SAINT JOHNS LANE, SUITE 109ELLICOTT CITY,...
# 31                    3315 PLAZA WAYWALDORF, MD 20603
#
#                           Company                  County  \
# 0                     AMIN NARGIS         Wicomico County
# 1                     AMIN NARGIS         Wicomico County
# 2           ANJ DISTRIBUTIONS LLC     Anne Arundel County
# 3       COX TRADING COMPANY L L C     Queen Anne's County
# 4                 COX TRADING LLC     Anne Arundel County
# 5   DISBROW II EMERSON HARRINGTON     Anne Arundel County
# 6      DISCOUNT TOBACCO ESSEX LLC           Howard County
# 7          FAIRGROUND VILLAGE LLC          Carroll County
# 8                  GRIMM JENNIFER       St. Mary's County
# 9                 HUTCH VAPES LLC     Queen Anne's County
# 10               HUTCHINS COX LLP     Queen Anne's County
# 11                JAMESON WILLIAM       St. Mary's County
# 12              JAMESON WILLIAM E          Charles County
# 13                JEFFERS MICHAEL       St. Mary's County
# 14              JEFFERS MICHAEL W  Prince George's County
# 15                   SHIN JENNY Y     Anne Arundel County
# 16               SHIN JENNY YOUNG           Howard County
# 17                  TAYLOR TRAVIS        Baltimore County
# 18            TRUE ENTERPRISE INC        Worcester County
# 19              VAPE  SOCIAL  LLC       Montgomery County
# 20                VAPE JUNGLE LLC          Charles County
# 21                  VAPE TIME LLC        Baltimore County
# 22            VAPEBAR EXPRESS LLC          Charles County
# 23                   VAPOR 99 LLC  Prince George's County
# 24                VAPOR ALLEY LLC           Talbot County
# 25          VAPOR EMPORIUM MD LLC        Frederick County
# 26               VAPOR VILLA CORP        Baltimore County
# 27               VAPOR VILLA CORP        Baltimore County
# 28          WALKER TRADING CO INC          Harford County
# 29     WALKER TRADING COMPANY INC        Baltimore County
# 30     WALKER TRADING COMPANY INC           Howard County
# 31           YARKHOUSE EMPIRE INC          Charles County
#
#                                               Details Issued Date Lic. Status  \
# 0   https://jportal.mdcourts.gov/license/pbLicense...   4/27/2017      Issued
# 1   https://jportal.mdcourts.gov/license/pbLicense...   4/27/2017      Issued
# 2   https://jportal.mdcourts.gov/license/pbLicense...   4/05/2017      Issued
# 3   https://jportal.mdcourts.gov/license/pbLicense...   5/31/2017      Issued
# 4                                                 NaN         NaN     Pending
# 5   https://jportal.mdcourts.gov/license/pbLicense...   4/13/2017      Issued
# 6   https://jportal.mdcourts.gov/license/pbLicense...   5/19/2017      Issued
# 7   https://jportal.mdcourts.gov/license/pbLicense...   4/21/2017      Issued
# 8                                                 NaN         NaN     Pending
# 9   https://jportal.mdcourts.gov/license/pbLicense...   4/13/2017      Issued
# 10                                                NaN         NaN     Pending
# 11  https://jportal.mdcourts.gov/license/pbLicense...   5/17/2017      Issued
# 12                                                NaN         NaN     Pending
# 13                                                NaN         NaN     Pending
# 14                                                NaN         NaN     Pending
# 15                                                NaN         NaN     Pending
# 16                                                NaN         NaN     Pending
# 17                                                NaN         NaN     Pending
# 18  https://jportal.mdcourts.gov/license/pbLicense...   5/05/2017      Issued
# 19  https://jportal.mdcourts.gov/license/pbLicense...   4/18/2017      Issued
# 20  https://jportal.mdcourts.gov/license/pbLicense...   3/31/2017      Issued
# 21                                                NaN         NaN     Pending
# 22                                                NaN         NaN     Pending
# 23  https://jportal.mdcourts.gov/license/pbLicense...   5/03/2017      Issued
# 24  https://jportal.mdcourts.gov/license/pbLicense...   5/10/2017      Issued
# 25  https://jportal.mdcourts.gov/license/pbLicense...   4/14/2017      Issued
# 26  https://jportal.mdcourts.gov/license/pbLicense...   4/12/2017      Issued
# 27  https://jportal.mdcourts.gov/license/pbLicense...   4/12/2017      Issued
# 28  https://jportal.mdcourts.gov/license/pbLicense...   4/03/2017      Issued
# 29                                                NaN         NaN     Pending
# 30  https://jportal.mdcourts.gov/license/pbLicense...   3/27/2017      Issued
# 31                                                NaN         NaN     Pending
#
#        License             Store
# 0   22173808.0  VAPE IT STORE II
# 1   22173807.0   VAPE IT STORE I
# 2    2104436.0       VAPEPAD THE
# 3   17165957.0         VAPE FROG
# 4          NaN         VAPE FROG
# 5    2102408.0   VAPE LOFT (THE)
# 6   13141786.0      VAPE N CIGAR
# 7    6126253.0         VAPE DOJO
# 8          NaN        VAPE HAVEN
# 9   17166688.0         VAPE BIRD
# 10         NaN         VAPE FROG
# 11  18167503.0     VAPORS LOUNGE
# 12         NaN     VAPORS LOUNGE
# 13         NaN         VAPIST MD
# 14         NaN     VAPIST MD LLC
# 15         NaN        VAPERTETMD
# 16         NaN        VAPERTEKMD
# 17         NaN          VAPORIOT
# 18  23178140.0         VAPE PLUS
# 19  15155429.0      VAPE  SOCIAL
# 20   8131285.0       VAPE JUNGLE
# 21         NaN         VAPE TIME
# 22         NaN    VAPEBAR EXPESS
# 23  16165362.0          VAPOR 99
# 24  20170900.0       VAPOR ALLEY
# 25  10135432.0    VAPOR EMPORIUM
# 26   3121958.0       VAPOR VILLA
# 27   3121959.0       VAPOR VILLA
# 28  12140135.0         VAPE DOJO
# 29         NaN         VAPE DOJO
# 30  13144108.0         VAPE DOJO
# 31         NaN   VAPEZ YARDHOUSE
