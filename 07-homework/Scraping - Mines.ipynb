# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm#MID), thank goodness we can search for these things.

# %% [markdown]
# ## Preparation: Knowing your tags
#
# These questions are the same for every data set, and might not work exactly for yours.
#
# **Search for every operator with 'dirt' in their name, including abandoned mines.**

# %% [markdown]
# ### What is the tag and class name for every row of data?

# %%
# <tr></tr>

# %% [markdown]
# ### What is the tag and class name for every mine operator's name?

# %%
# <font style="FONT-SIZE:.75em;"></font>

# %% [markdown]
# ### What is the tag and class name for every mine's name?

# %%
# the same as above?

# %% [markdown]
# ### What is the tag and class name for every mine operator's name?

# %%
# as above so below?

# %% [markdown]
# ### What is the tag and class name for every mine operator's name?

# %%
# "below"

# %% [markdown]
# ## Being lazy
#
# If you only needed these results, what would you do instead of scraping them?

# %%
# ¯\_(ツ)_/¯

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# Use `requests`, not `urllib`.

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://arlweb.msha.gov/drs/ASP/OprNameStatesearch.asp'
data = {
    'OperSearch':'dirt',
    'Abandoned':'No',
    'MineName':'',
    'StateSearch':'None',
    'CM':'All',
    'x':'23',
    'y':'1',
    'MC':'Opersearch'
}

response = requests.post(url, data = data)
doc = BeautifulSoup(response.text, 'html.parser')
doc
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
#
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!-- ****************************************** Begin META TAGS ********************************************* -->
# <meta content="NOINDEX, NOFOLLOW" name="ROBOTS"/>
# <!-- ****************************************** End META TAGS *********************************************** -->
# <title>MSHA  - Mine  Data Retrieval System - Basic Mine Information Page</title>
# <script src="/2010redesign/Scripts/federated-analytics.js" type="text/javascript"></script>
# <script src="/2010redesign/Scripts/AC_RunActiveContent.js" type="text/javascript"></script>
# <link href="/2010Redesign/includes/Print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="/2010Redesign/Includes/MSHAwebnew.css" media="screen" rel="stylesheet" type="text/css">
# <link href="/2010Redesign/includes/style-screen.css" media="screen" rel="stylesheet" type="text/css"/>
# </link></head>
# <body>
# <link href="https://webapps.dol.gov/FSPublic/Content/W_Helpful.css" rel="stylesheet" type="text/css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.7.1/jquery.min.js" type="text/JavaScript"></script>
# <script id="_fed_an_ua_tag" src="/res/js/dap.min.js?agency=DOL&amp;subagency=MSHA" type="text/javascript"></script>
# <!--<script language="javascript" id="_fed_an_ua_tag" src="/res/js/federated-analytics.min.js?agency=DOL&subagency=MSHA"></script>-->
# <script src="https://webapps.dol.gov/FSPublic/Scripts/W_Helpful.js" type="text/JavaScript"></script>
# <script type="text/JavaScript">
# 	$(document).ready(function() {
# 		W_Helpful.init('#fbcontent');
# 	});(jQuery);
# </script>
# <script><!-- ************* GOOGLE ANALYTICS ****************** -->
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-52441844-1', 'auto');
# 	ga('send', 'pageview');
#
# 	$(document).ready( function() {
# 		$("a[href$='pdf']").each(function() {
# 			eventName=$(this).attr('href');
# 			eventClick="ga('send','event','PDF','Download','"+eventName+"');";
# 			$(this).attr("onClick",eventClick);
# 		});
# 	});
# </script>
# <div style="display:none;"><a href="#content">Skip to content</a></div>
# <div id="header">
# <div id="searchMSHA">
# <a href="https://mshasearch.msha.gov/search?access=p&amp;entqr=0&amp;output=xml_no_dtd&amp;sort=date%3AD%3AL%3Ad1&amp;ie=UTF-8&amp;lr=&amp;client=MSHASearch&amp;ud=1&amp;site=AllDocuments&amp;oe=UTF-8&amp;proxystylesheet=MSHASearch&amp;ip=&amp;proxycustom=%3CADVANCED/%3E">
# <div color="#FFFFFF" style="margin: -3px 0 3px 0;"><b>Additional Search Options</b></div>
# </a>
# <form action="https://mshasearch.msha.gov/search" method="get" target="_self">
# <!--<form method="get" target="_self" action="/services/searchNotice.asp"> -->
# <label class="scr-rdr" for="mshaSearchField">Find it at MSHA</label>
# <input id="mshaSearchField" name="q" onclick="this.value='';" style="color:#990000;" type="text" value="Find It at MSHA"/>
# <input class="searchBtn" name="search" style="color:#990000; font-weight: bold; font-family: Arial, sans-serif; height: 22px; padding: 0px; font-size:0.9em; width: 60px; padding-right: 2px;" type="submit" value="SEARCH">
# <input name="client" type="hidden" value="MSHASearch"/>
# <input name="output" type="hidden" value="xml_no_dtd"/>
# <input name="proxystylesheet" type="hidden" value="MSHASearch"/>
# <input name="filter" type="hidden" value="p"/>
# <input name="getfields" type="hidden" value="*"/>
# <input name="site" type="hidden" value="AllDocuments"/>
# </input></form>
# </div>
# <div id="subscribe">
# <script src="https://public.govdelivery.com/javascripts/cache/snippet.js" type="text/javascript"></script>
# <form accept-charset="UTF-8" action="https://public.govdelivery.com/accounts/USDOL/subscriber/qualify?qsp=USDOL_2585" method="post">
# <div style="margin:0;padding:0;display:inline;color:#fff;font-size: 12px;">
# <input name="utf8" type="hidden" value="Ã¢ÂÂ">
# <input name="authenticity_token" type="hidden" value="4BAzX1/DPLa9DIarEHPs6w3ymvDs6SIgrYFizEOhBMs=">
# </input></input></div>
# <div style="color:#ffffff;font-family:Verdana, Geneva, Arial, Helvetica, sans-serif;font-style:normal;font-size: 12px;border-radius:0px !important;">
# <fieldset style="border:none; border-radius:0px !important; padding: 0px; margin: 0; font-size: 12px;;">
# <b>Subscribe to Email Updates</b><br/>
# <input class="long" id="email" name="email" style="height: 22px; border-width: 1px;padding:none;color:#990000; width: 180px; font-family: Verdana; font-style:normal;font-size:10pt; font-weight: 400; margin-right: 5px; display: inline-block; box-sizing: border-box; padding: 0 !important;" type="text">
# <div class="button_panel" style="float:right;">
# <input class="searchBtn" name="commit" style="color:#990000; font-weight: bold; font-style: uppercase;font-family: Arial, sans-serif; border: none; height: 22px; padding: 0px; font-size:0.9em; width: 60px; padding-right: 2px;" type="submit" value="SUBMIT">
# </input></div>
# </input></fieldset>
# </div>
# </form>
# <script type="text/javascript">
# 	  //<![CDATA[
# 		new GD.view.AccountSubscribersNew({
# 		  facebookAppId: "188927694463050",
# 		  facebookLoginURL: "/accounts/USDOL/facebook_subscriber/login",
# 		  wirelessEnabled: true
# 		}).init();
# 	  //]]>
# 	</script>
# </div>
# <div id="dol_logo">
# <a href="http://www.dol.gov/">
# <img alt="Seal of the United States Department of Labor" border="0" src="/images/dol_sym.gif"/></a>
# </div>
# <div id="headText">
# <span id="dol1">
# <a href="http://www.dol.gov">
# 				UNITED STATES<br/>
# 				DEPARTMENT OF LABOR
# 			</a>
# </span>
# </div>
# <div style="clear:both;"></div>
# <div id="headlinks">
# <a href="/indexes/atozpage.asp">A-Z Index</a> |
# 		<a href="/siteindex/siteindex.asp">Site Map</a> |
# 		<a href="/faq/faqhome.htm">FAQs</a> |
# 		<a href="/forms/forms.asp">MSHA Forms</a> |
# 		<a href="/contactmsha/contactmsha.htm">Contact Us</a> |
#
# <!-- 		<script language="JavaScript">
# 			var pagePath = location.href.split(location.host)[1];
# 			document.write("<a href=\"http://es.arlweb.msha.gov.systranlinks.net/" + pagePath + " \" target=\"new_window\">");
# 			document.write("Espa&ntilde;ol</a>");
# 		</script> -->
# <span id="google_translate_element"></span>
# <style>
# 			span#google_translate_element {
# 				float: right;
# 				margin-top: -5px;
# 			}
# 			a.goog-te-menu-value > span {
# 			    color: #000000;
# 			}
# 		</style>
# <script type="text/javascript">
# 			function googleTranslateElementInit() {
# 			  new google.translate.TranslateElement({
# 			  	pageLanguage: 'en',
# 			  	includedLanguages: 'en,es',
# 			  	layout: google.translate.TranslateElement.InlineLayout.SIMPLE,
# 			  	gaTrack: true, gaId: 'UA-52441844-1'
# 			  }, 'google_translate_element');
# 			}
# 		</script>
# <script src="//translate.google.com/translate_a/element.js?cb=googleTranslateElementInit" type="text/javascript"></script>
# </div>
# <div style="clear:both;"></div>
# <div id="three">
# <div id="hcontent">
# <div id="agency">
# <a href="http://www.msha.gov" style="text-decoration:none;">Mine Safety and Health Administration - MSHA</a>
# <!-- AddThis Button BEGIN -->
# <a class="addthis_button" href="http://www.addthis.com/bookmark.php?v=300&amp;pubid=ra-52d534a46402ec50" style="margin-left: 230px">
# <img alt="Bookmark and Share" height="16" src="https://s7.addthis.com/static/btn/v2/lg-share-en.gif" style="border:0" width="125"/>
# </a>
# <script type="text/javascript">var addthis_config = {"data_track_addressbar":false};</script>
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-52d534a46402ec50" type="text/javascript"></script>
# <!-- AddThis Button END -->
# <br/>    <a href="http://www.msha.gov" style="text-decoration:none;">  - Protecting Miners' Safety and Health Since 1978</a>
# </div>
# <div id="headImg">
# <script language="JavaScript">
# 					if (window.print) {
# 						document.write('<form><input type=button name=print value="Print This Page" onClick="window.print()"></form>');
# 					}
# 				</script>
# <div class="utilitybarright" style=" width: 150px; margin-top: 5px;">
# <div id="fbcontent" style="float:right"></div>
# </div>
# </div> <!-- End Agency -->
# </div>
# </div> <!-- End three -->
# </div><!-- End Header -->
# <div id="headSeparator"></div>
# <!-- This ends the newheader.asp content-->
# <div id="container">
# <!-- This begins the page content section-->
# <div id="content">
# <table border="0" width="100%">
# <tr>
# <td width="30%"><a href="/drs/drshome.htm"><img alt="Mine Data Retrieval System" border="0" height="75" src="/drs/images/drslogo.png" width="300"/></a></td>
# <th width="40%"><font style="FONT-SIZE:1.20em;">Operator Name or Mine Name<br/> Search</font></th>
# <td width="30%"> </td></tr></table>
# <br/>
# <!-- Output FORM -->
# <table align="center" bgcolor="#FFFFFF" border="0" cellpadding="3" width="90%">
# <tr>
# <td valign="top" width="50%">
# <table width="100%">
# <tr>
# <td><font style="FONT-SIZE:.80em;"><b>Abandoned*</b></font></td></tr>
# <tr>
# <td valign="top" width="95%"><font style="FONT-SIZE:.75em;">Indicates Mine is Abandoned and Sealed</font></td></tr></table></td>
# <td align="right" valign="top" width="50%">
# <table align="right" width="100%">
# <tr>
# <td align="right" colspan="2"><font style="FONT-SIZE:.80em;"><b>*CM (Coal or Metal Mine/Nonmetal Mine)</b></font></td></tr>
# <tr>
# <td align="right" width="46%"><font style="FONT-SIZE:.80em;">C<br/>M</font></td>
# <td width="54%"><font style="FONT-SIZE:.80em;">...... Coal<br/>...... Metal/Nonmetal</font></td></tr>
# </table></td></tr></table>
# <br/>
# <table align="center" bgcolor="LemonChiffon" border="1" bordercolordark="Black" bordercolorlight="Gray" cellpadding="5" cellspacing="1" width="95%">
# <tr>
# <th bgcolor="#D7D7D6" width="10%"><font style="FONT-SIZE:.75em;">ID</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">State</font></th>
# <th bgcolor="#D7D7D6" width="20%"><font style="FONT-SIZE:.75em;">Operator</font></th>
# <th bgcolor="#D7D7D6" width="20%"><font style="FONT-SIZE:.75em;">Mine Name</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">Type</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">CM*</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">Status</font></th>
# <th bgcolor="#D7D7D6" width="20%"><font style="FONT-SIZE:.75em;">Commodity</font></th>
# <th bgcolor="#D7D7D6" width="10%"><font style="FONT-SIZE:.75em;">More Info</font></th></tr>
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3503598"/><font style="FONT-SIZE:.75em;">3503598</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>OR</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --> Newberg Rock &amp; Dirt<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Newberg Rock &amp; Dirt<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Crushed, Broken Stone NEC  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr></table></div></div></body>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4801789"/><font style="FONT-SIZE:.75em;">4801789</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>ND</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->AM Dirtworks &amp; Aggregate Sales<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->AM Dirtworks &amp; Aggregate Sales<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="5001797"/><font style="FONT-SIZE:.75em;">5001797</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>AK</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Company<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Bush Pilot<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4608254"/><font style="FONT-SIZE:.75em;">4608254</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>WV</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Con<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Hog Lick Quarry<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Temporarily Idled  </font></td>
# <td><font style="FONT-SIZE:.75em;">Crushed, Broken Limestone NEC  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="2103723"/><font style="FONT-SIZE:.75em;">2103723</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>MN</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Doctor Inc<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Rock Lake Plant<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4104757"/><font style="FONT-SIZE:.75em;">4104757</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>TX</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Works<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Portable #1<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="0801306"/><font style="FONT-SIZE:.75em;">0801306</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>FL</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Holley Dirt Company, Inc<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->River Road Pit<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Sand, Common  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3901432"/><font style="FONT-SIZE:.75em;">3901432</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>SD</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Krueger Brothers Gravel &amp; Dirt<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->PORTABLE SCREENER<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3609624"/><font style="FONT-SIZE:.75em;">3609624</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>PA</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->M R Dirt<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Forbes Pit<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3609931"/><font style="FONT-SIZE:.75em;">3609931</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>PA</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->M.R. Dirt Inc.<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Camptown Quarry<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Dimension Stone NEC  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="1519799"/><font style="FONT-SIZE:.75em;">1519799</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>KY</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->P B Dirt Movers, Inc<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Fedscreek Surface<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->C<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Coal (Bituminous)  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4407296"/><font style="FONT-SIZE:.75em;">4407296</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VA</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->PB Dirt Movers<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Mine No. 6<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Underground         <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->C<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Temporarily Idled  </font></td>
# <td><font style="FONT-SIZE:.75em;">Coal (Bituminous)  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4407270"/><font style="FONT-SIZE:.75em;">4407270</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VA</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->PB Dirt Movers, Inc<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface Mine No. 1<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->C<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">NonProducing  </font></td>
# <td><font style="FONT-SIZE:.75em;">Coal (Bituminous)  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="0203332"/><font style="FONT-SIZE:.75em;">0203332</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>AZ</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Prescott Dirt, LLC<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Sandretto Drive<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="2901986"/><font style="FONT-SIZE:.75em;">2901986</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>NM</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->R D Blankenship Dirt Work LLC<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->R D BLANKENSHIP DIRT WORK<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4300768"/><font style="FONT-SIZE:.75em;">4300768</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VT</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->SIMPSON DIRTWORX LLC<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Pettibone Jaw Crusher<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4300776"/><font style="FONT-SIZE:.75em;">4300776</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VT</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->SIMPSON DIRTWORX LLC<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Chieftan 1400<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="2302283"/><font style="FONT-SIZE:.75em;">2302283</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>MO</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Spry's Dirt &amp; Gravel, Inc.<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Mike's Money Pit<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="2103518"/><font style="FONT-SIZE:.75em;">2103518</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>MN</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Vogt Dirt Service<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Crusher<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td bgcolor="#000000" colspan="8"><font style="FONT-SIZE:.75em; color:#FFF"><b>Total Number of Mines Found:</b>  <b>19</b></font></td></tr>
#
#
# <p> </p>
# <p> </p>
# <div>
# <a href="/drs/drshome.htm" title="DRS Home Page"><img align="middle" alt="Return to DRS Home Page" border="0" height="18" src="/headerfooter/drshomepage.jpg" width="18"/></a>  <a href="/drs/drshome.htm" title="DRS Home Page"><b><font color="Maroon" style="FONT-SIZE:8pt; FONT-FAMILY: Verdana, Arial, Helvetica, Sans-serif">Return to DRS Home Page</font></b></a> </div>
#
#
# <!-- This ends the page content-->
#
#
# <!--This Starts the Footer--> <div id="footer">
# <div style="clear:both;"></div>
# <div id="fone"><a href="/faq/faqhome.htm">FAQs</a> |
# 				<a href="/readroom/readroom.htm">Freedom of Information Act</a> |
# 				<a href="/privacy.htm">Privacy &amp; Security Statement</a> |
# 				<a href="/disclaim.htm">Disclaimers</a> |
#
# 				<a href="/forms/helpdesk.asp" target="_blank" title="Forms Help Desk">Online Filing Help Desk</a>  |
#                  <a href="/contactmsha/contactmsha.htm">Contact Us</a></div>
# <div id="ftwo">U.S. Department of Labor | Mine Safety and Health Administration (MSHA) | 201 12th Street South, Suite 401 | Arlington, VA 22202-5450<br>
# <a href="http://www.msha.gov" style="text-decoration: underline;">www.msha.gov</a> | <a href="http://www.dol.gov/dol/contact/contact-phonecallcenter.htm">TTY</a> | Telephone:  (202) 693-9400</br></div>
# </div>
# <!--This Ends the Footer-->
# <!--Footer End -->

# %% [markdown]
# ## Try to scrape the page
#
# To test if you requested the page correctly, save the BeautifulSoup document as `doc` and run the code `doc.find_all('tr')[-1].text` to get the text of the last `<tr>` element.
#
# - If the result starts with **Total Number of Mines Found**, you were successful.

# %%
doc.find_all('tr')[-1]
# Out:
# <tr>
# <td bgcolor="#000000" colspan="8"><font style="FONT-SIZE:.75em; color:#FFF"><b>Total Number of Mines Found:</b>  <b>19</b></font></td></tr>

# %% [markdown]
# ## Actually scraping

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be your data. What is the index of the first row element that is actually a result?
#
# `.text` will help you here.

# %%
doc
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
#
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!-- ****************************************** Begin META TAGS ********************************************* -->
# <meta content="NOINDEX, NOFOLLOW" name="ROBOTS"/>
# <!-- ****************************************** End META TAGS *********************************************** -->
# <title>MSHA  - Mine  Data Retrieval System - Basic Mine Information Page</title>
# <script src="/2010redesign/Scripts/federated-analytics.js" type="text/javascript"></script>
# <script src="/2010redesign/Scripts/AC_RunActiveContent.js" type="text/javascript"></script>
# <link href="/2010Redesign/includes/Print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="/2010Redesign/Includes/MSHAwebnew.css" media="screen" rel="stylesheet" type="text/css">
# <link href="/2010Redesign/includes/style-screen.css" media="screen" rel="stylesheet" type="text/css"/>
# </link></head>
# <body>
# <link href="https://webapps.dol.gov/FSPublic/Content/W_Helpful.css" rel="stylesheet" type="text/css"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.7.1/jquery.min.js" type="text/JavaScript"></script>
# <script id="_fed_an_ua_tag" src="/res/js/dap.min.js?agency=DOL&amp;subagency=MSHA" type="text/javascript"></script>
# <!--<script language="javascript" id="_fed_an_ua_tag" src="/res/js/federated-analytics.min.js?agency=DOL&subagency=MSHA"></script>-->
# <script src="https://webapps.dol.gov/FSPublic/Scripts/W_Helpful.js" type="text/JavaScript"></script>
# <script type="text/JavaScript">
# 	$(document).ready(function() {
# 		W_Helpful.init('#fbcontent');
# 	});(jQuery);
# </script>
# <script><!-- ************* GOOGLE ANALYTICS ****************** -->
# 	(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	})(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
# 	ga('create', 'UA-52441844-1', 'auto');
# 	ga('send', 'pageview');
#
# 	$(document).ready( function() {
# 		$("a[href$='pdf']").each(function() {
# 			eventName=$(this).attr('href');
# 			eventClick="ga('send','event','PDF','Download','"+eventName+"');";
# 			$(this).attr("onClick",eventClick);
# 		});
# 	});
# </script>
# <div style="display:none;"><a href="#content">Skip to content</a></div>
# <div id="header">
# <div id="searchMSHA">
# <a href="https://mshasearch.msha.gov/search?access=p&amp;entqr=0&amp;output=xml_no_dtd&amp;sort=date%3AD%3AL%3Ad1&amp;ie=UTF-8&amp;lr=&amp;client=MSHASearch&amp;ud=1&amp;site=AllDocuments&amp;oe=UTF-8&amp;proxystylesheet=MSHASearch&amp;ip=&amp;proxycustom=%3CADVANCED/%3E">
# <div color="#FFFFFF" style="margin: -3px 0 3px 0;"><b>Additional Search Options</b></div>
# </a>
# <form action="https://mshasearch.msha.gov/search" method="get" target="_self">
# <!--<form method="get" target="_self" action="/services/searchNotice.asp"> -->
# <label class="scr-rdr" for="mshaSearchField">Find it at MSHA</label>
# <input id="mshaSearchField" name="q" onclick="this.value='';" style="color:#990000;" type="text" value="Find It at MSHA"/>
# <input class="searchBtn" name="search" style="color:#990000; font-weight: bold; font-family: Arial, sans-serif; height: 22px; padding: 0px; font-size:0.9em; width: 60px; padding-right: 2px;" type="submit" value="SEARCH">
# <input name="client" type="hidden" value="MSHASearch"/>
# <input name="output" type="hidden" value="xml_no_dtd"/>
# <input name="proxystylesheet" type="hidden" value="MSHASearch"/>
# <input name="filter" type="hidden" value="p"/>
# <input name="getfields" type="hidden" value="*"/>
# <input name="site" type="hidden" value="AllDocuments"/>
# </input></form>
# </div>
# <div id="subscribe">
# <script src="https://public.govdelivery.com/javascripts/cache/snippet.js" type="text/javascript"></script>
# <form accept-charset="UTF-8" action="https://public.govdelivery.com/accounts/USDOL/subscriber/qualify?qsp=USDOL_2585" method="post">
# <div style="margin:0;padding:0;display:inline;color:#fff;font-size: 12px;">
# <input name="utf8" type="hidden" value="Ã¢ÂÂ">
# <input name="authenticity_token" type="hidden" value="4BAzX1/DPLa9DIarEHPs6w3ymvDs6SIgrYFizEOhBMs=">
# </input></input></div>
# <div style="color:#ffffff;font-family:Verdana, Geneva, Arial, Helvetica, sans-serif;font-style:normal;font-size: 12px;border-radius:0px !important;">
# <fieldset style="border:none; border-radius:0px !important; padding: 0px; margin: 0; font-size: 12px;;">
# <b>Subscribe to Email Updates</b><br/>
# <input class="long" id="email" name="email" style="height: 22px; border-width: 1px;padding:none;color:#990000; width: 180px; font-family: Verdana; font-style:normal;font-size:10pt; font-weight: 400; margin-right: 5px; display: inline-block; box-sizing: border-box; padding: 0 !important;" type="text">
# <div class="button_panel" style="float:right;">
# <input class="searchBtn" name="commit" style="color:#990000; font-weight: bold; font-style: uppercase;font-family: Arial, sans-serif; border: none; height: 22px; padding: 0px; font-size:0.9em; width: 60px; padding-right: 2px;" type="submit" value="SUBMIT">
# </input></div>
# </input></fieldset>
# </div>
# </form>
# <script type="text/javascript">
# 	  //<![CDATA[
# 		new GD.view.AccountSubscribersNew({
# 		  facebookAppId: "188927694463050",
# 		  facebookLoginURL: "/accounts/USDOL/facebook_subscriber/login",
# 		  wirelessEnabled: true
# 		}).init();
# 	  //]]>
# 	</script>
# </div>
# <div id="dol_logo">
# <a href="http://www.dol.gov/">
# <img alt="Seal of the United States Department of Labor" border="0" src="/images/dol_sym.gif"/></a>
# </div>
# <div id="headText">
# <span id="dol1">
# <a href="http://www.dol.gov">
# 				UNITED STATES<br/>
# 				DEPARTMENT OF LABOR
# 			</a>
# </span>
# </div>
# <div style="clear:both;"></div>
# <div id="headlinks">
# <a href="/indexes/atozpage.asp">A-Z Index</a> |
# 		<a href="/siteindex/siteindex.asp">Site Map</a> |
# 		<a href="/faq/faqhome.htm">FAQs</a> |
# 		<a href="/forms/forms.asp">MSHA Forms</a> |
# 		<a href="/contactmsha/contactmsha.htm">Contact Us</a> |
#
# <!-- 		<script language="JavaScript">
# 			var pagePath = location.href.split(location.host)[1];
# 			document.write("<a href=\"http://es.arlweb.msha.gov.systranlinks.net/" + pagePath + " \" target=\"new_window\">");
# 			document.write("Espa&ntilde;ol</a>");
# 		</script> -->
# <span id="google_translate_element"></span>
# <style>
# 			span#google_translate_element {
# 				float: right;
# 				margin-top: -5px;
# 			}
# 			a.goog-te-menu-value > span {
# 			    color: #000000;
# 			}
# 		</style>
# <script type="text/javascript">
# 			function googleTranslateElementInit() {
# 			  new google.translate.TranslateElement({
# 			  	pageLanguage: 'en',
# 			  	includedLanguages: 'en,es',
# 			  	layout: google.translate.TranslateElement.InlineLayout.SIMPLE,
# 			  	gaTrack: true, gaId: 'UA-52441844-1'
# 			  }, 'google_translate_element');
# 			}
# 		</script>
# <script src="//translate.google.com/translate_a/element.js?cb=googleTranslateElementInit" type="text/javascript"></script>
# </div>
# <div style="clear:both;"></div>
# <div id="three">
# <div id="hcontent">
# <div id="agency">
# <a href="http://www.msha.gov" style="text-decoration:none;">Mine Safety and Health Administration - MSHA</a>
# <!-- AddThis Button BEGIN -->
# <a class="addthis_button" href="http://www.addthis.com/bookmark.php?v=300&amp;pubid=ra-52d534a46402ec50" style="margin-left: 230px">
# <img alt="Bookmark and Share" height="16" src="https://s7.addthis.com/static/btn/v2/lg-share-en.gif" style="border:0" width="125"/>
# </a>
# <script type="text/javascript">var addthis_config = {"data_track_addressbar":false};</script>
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-52d534a46402ec50" type="text/javascript"></script>
# <!-- AddThis Button END -->
# <br/>    <a href="http://www.msha.gov" style="text-decoration:none;">  - Protecting Miners' Safety and Health Since 1978</a>
# </div>
# <div id="headImg">
# <script language="JavaScript">
# 					if (window.print) {
# 						document.write('<form><input type=button name=print value="Print This Page" onClick="window.print()"></form>');
# 					}
# 				</script>
# <div class="utilitybarright" style=" width: 150px; margin-top: 5px;">
# <div id="fbcontent" style="float:right"></div>
# </div>
# </div> <!-- End Agency -->
# </div>
# </div> <!-- End three -->
# </div><!-- End Header -->
# <div id="headSeparator"></div>
# <!-- This ends the newheader.asp content-->
# <div id="container">
# <!-- This begins the page content section-->
# <div id="content">
# <table border="0" width="100%">
# <tr>
# <td width="30%"><a href="/drs/drshome.htm"><img alt="Mine Data Retrieval System" border="0" height="75" src="/drs/images/drslogo.png" width="300"/></a></td>
# <th width="40%"><font style="FONT-SIZE:1.20em;">Operator Name or Mine Name<br/> Search</font></th>
# <td width="30%"> </td></tr></table>
# <br/>
# <!-- Output FORM -->
# <table align="center" bgcolor="#FFFFFF" border="0" cellpadding="3" width="90%">
# <tr>
# <td valign="top" width="50%">
# <table width="100%">
# <tr>
# <td><font style="FONT-SIZE:.80em;"><b>Abandoned*</b></font></td></tr>
# <tr>
# <td valign="top" width="95%"><font style="FONT-SIZE:.75em;">Indicates Mine is Abandoned and Sealed</font></td></tr></table></td>
# <td align="right" valign="top" width="50%">
# <table align="right" width="100%">
# <tr>
# <td align="right" colspan="2"><font style="FONT-SIZE:.80em;"><b>*CM (Coal or Metal Mine/Nonmetal Mine)</b></font></td></tr>
# <tr>
# <td align="right" width="46%"><font style="FONT-SIZE:.80em;">C<br/>M</font></td>
# <td width="54%"><font style="FONT-SIZE:.80em;">...... Coal<br/>...... Metal/Nonmetal</font></td></tr>
# </table></td></tr></table>
# <br/>
# <table align="center" bgcolor="LemonChiffon" border="1" bordercolordark="Black" bordercolorlight="Gray" cellpadding="5" cellspacing="1" width="95%">
# <tr>
# <th bgcolor="#D7D7D6" width="10%"><font style="FONT-SIZE:.75em;">ID</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">State</font></th>
# <th bgcolor="#D7D7D6" width="20%"><font style="FONT-SIZE:.75em;">Operator</font></th>
# <th bgcolor="#D7D7D6" width="20%"><font style="FONT-SIZE:.75em;">Mine Name</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">Type</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">CM*</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">Status</font></th>
# <th bgcolor="#D7D7D6" width="20%"><font style="FONT-SIZE:.75em;">Commodity</font></th>
# <th bgcolor="#D7D7D6" width="10%"><font style="FONT-SIZE:.75em;">More Info</font></th></tr>
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3503598"/><font style="FONT-SIZE:.75em;">3503598</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>OR</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --> Newberg Rock &amp; Dirt<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Newberg Rock &amp; Dirt<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Crushed, Broken Stone NEC  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr></table></div></div></body>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4801789"/><font style="FONT-SIZE:.75em;">4801789</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>ND</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->AM Dirtworks &amp; Aggregate Sales<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->AM Dirtworks &amp; Aggregate Sales<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="5001797"/><font style="FONT-SIZE:.75em;">5001797</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>AK</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Company<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Bush Pilot<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4608254"/><font style="FONT-SIZE:.75em;">4608254</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>WV</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Con<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Hog Lick Quarry<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Temporarily Idled  </font></td>
# <td><font style="FONT-SIZE:.75em;">Crushed, Broken Limestone NEC  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="2103723"/><font style="FONT-SIZE:.75em;">2103723</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>MN</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Doctor Inc<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Rock Lake Plant<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4104757"/><font style="FONT-SIZE:.75em;">4104757</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>TX</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Works<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Portable #1<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="0801306"/><font style="FONT-SIZE:.75em;">0801306</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>FL</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Holley Dirt Company, Inc<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->River Road Pit<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Sand, Common  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3901432"/><font style="FONT-SIZE:.75em;">3901432</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>SD</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Krueger Brothers Gravel &amp; Dirt<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->PORTABLE SCREENER<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3609624"/><font style="FONT-SIZE:.75em;">3609624</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>PA</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->M R Dirt<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Forbes Pit<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3609931"/><font style="FONT-SIZE:.75em;">3609931</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>PA</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->M.R. Dirt Inc.<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Camptown Quarry<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Dimension Stone NEC  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="1519799"/><font style="FONT-SIZE:.75em;">1519799</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>KY</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->P B Dirt Movers, Inc<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Fedscreek Surface<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->C<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Coal (Bituminous)  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4407296"/><font style="FONT-SIZE:.75em;">4407296</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VA</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->PB Dirt Movers<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Mine No. 6<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Underground         <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->C<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Temporarily Idled  </font></td>
# <td><font style="FONT-SIZE:.75em;">Coal (Bituminous)  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4407270"/><font style="FONT-SIZE:.75em;">4407270</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VA</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->PB Dirt Movers, Inc<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface Mine No. 1<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->C<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">NonProducing  </font></td>
# <td><font style="FONT-SIZE:.75em;">Coal (Bituminous)  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="0203332"/><font style="FONT-SIZE:.75em;">0203332</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>AZ</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Prescott Dirt, LLC<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Sandretto Drive<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="2901986"/><font style="FONT-SIZE:.75em;">2901986</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>NM</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->R D Blankenship Dirt Work LLC<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->R D BLANKENSHIP DIRT WORK<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4300768"/><font style="FONT-SIZE:.75em;">4300768</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VT</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->SIMPSON DIRTWORX LLC<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Pettibone Jaw Crusher<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="4300776"/><font style="FONT-SIZE:.75em;">4300776</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VT</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->SIMPSON DIRTWORX LLC<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Chieftan 1400<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="2302283"/><font style="FONT-SIZE:.75em;">2302283</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>MO</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Spry's Dirt &amp; Gravel, Inc.<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Mike's Money Pit<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="2103518"/><font style="FONT-SIZE:.75em;">2103518</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>MN</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Vogt Dirt Service<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Crusher<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
# <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>
#
# <tr>
# <td bgcolor="#000000" colspan="8"><font style="FONT-SIZE:.75em; color:#FFF"><b>Total Number of Mines Found:</b>  <b>19</b></font></td></tr>
#
#
# <p> </p>
# <p> </p>
# <div>
# <a href="/drs/drshome.htm" title="DRS Home Page"><img align="middle" alt="Return to DRS Home Page" border="0" height="18" src="/headerfooter/drshomepage.jpg" width="18"/></a>  <a href="/drs/drshome.htm" title="DRS Home Page"><b><font color="Maroon" style="FONT-SIZE:8pt; FONT-FAMILY: Verdana, Arial, Helvetica, Sans-serif">Return to DRS Home Page</font></b></a> </div>
#
#
# <!-- This ends the page content-->
#
#
# <!--This Starts the Footer--> <div id="footer">
# <div style="clear:both;"></div>
# <div id="fone"><a href="/faq/faqhome.htm">FAQs</a> |
# 				<a href="/readroom/readroom.htm">Freedom of Information Act</a> |
# 				<a href="/privacy.htm">Privacy &amp; Security Statement</a> |
# 				<a href="/disclaim.htm">Disclaimers</a> |
#
# 				<a href="/forms/helpdesk.asp" target="_blank" title="Forms Help Desk">Online Filing Help Desk</a>  |
#                  <a href="/contactmsha/contactmsha.htm">Contact Us</a></div>
# <div id="ftwo">U.S. Department of Labor | Mine Safety and Health Administration (MSHA) | 201 12th Street South, Suite 401 | Arlington, VA 22202-5450<br>
# <a href="http://www.msha.gov" style="text-decoration: underline;">www.msha.gov</a> | <a href="http://www.dol.gov/dol/contact/contact-phonecallcenter.htm">TTY</a> | Telephone:  (202) 693-9400</br></div>
# </div>
# <!--This Ends the Footer-->
# <!--Footer End -->

# %%
columns = doc.find_all('tr')[6]
columns
# Out:
# <tr>
# <th bgcolor="#D7D7D6" width="10%"><font style="FONT-SIZE:.75em;">ID</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">State</font></th>
# <th bgcolor="#D7D7D6" width="20%"><font style="FONT-SIZE:.75em;">Operator</font></th>
# <th bgcolor="#D7D7D6" width="20%"><font style="FONT-SIZE:.75em;">Mine Name</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">Type</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">CM*</font></th>
# <th bgcolor="#D7D7D6" width="5%"><font style="FONT-SIZE:.75em;">Status</font></th>
# <th bgcolor="#D7D7D6" width="20%"><font style="FONT-SIZE:.75em;">Commodity</font></th>
# <th bgcolor="#D7D7D6" width="10%"><font style="FONT-SIZE:.75em;">More Info</font></th></tr>

# %%
first_row = doc.find_all('tr')[7]
first_row
# Out:
# <tr>
# <td align="center">
# <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
# <input name="MineId" type="hidden" value="3503598"/><font style="FONT-SIZE:.75em;">3503598</font>
# </form></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>OR</b><!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT --> Newberg Rock &amp; Dirt<!-- /DNT -->  </font></td>
# <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Newberg Rock &amp; Dirt<!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
# <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
# <td><font style="FONT-SIZE:.75em;">Active  </font></td>
# <td><font style="FONT-SIZE:.75em;">Crushed, Broken Stone NEC  </font></td>
# <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# Use LIST SLICING to skip the non-data row(s).

# %%
results = doc.find_all('tr')[7:]
results
# Out:
# [<tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="3503598"/><font style="FONT-SIZE:.75em;">3503598</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>OR</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --> Newberg Rock &amp; Dirt<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Newberg Rock &amp; Dirt<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Active  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Crushed, Broken Stone NEC  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="4801789"/><font style="FONT-SIZE:.75em;">4801789</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>ND</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->AM Dirtworks &amp; Aggregate Sales<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->AM Dirtworks &amp; Aggregate Sales<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="5001797"/><font style="FONT-SIZE:.75em;">5001797</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>AK</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Company<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Bush Pilot<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="4608254"/><font style="FONT-SIZE:.75em;">4608254</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>WV</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Con<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Hog Lick Quarry<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Temporarily Idled  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Crushed, Broken Limestone NEC  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="2103723"/><font style="FONT-SIZE:.75em;">2103723</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>MN</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Doctor Inc<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Rock Lake Plant<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="4104757"/><font style="FONT-SIZE:.75em;">4104757</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>TX</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Dirt Works<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Portable #1<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="0801306"/><font style="FONT-SIZE:.75em;">0801306</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>FL</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Holley Dirt Company, Inc<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->River Road Pit<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Active  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Sand, Common  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="3901432"/><font style="FONT-SIZE:.75em;">3901432</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>SD</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Krueger Brothers Gravel &amp; Dirt<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->PORTABLE SCREENER<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="3609624"/><font style="FONT-SIZE:.75em;">3609624</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>PA</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->M R Dirt<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Forbes Pit<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="3609931"/><font style="FONT-SIZE:.75em;">3609931</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>PA</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->M.R. Dirt Inc.<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Camptown Quarry<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Dimension Stone NEC  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="1519799"/><font style="FONT-SIZE:.75em;">1519799</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>KY</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->P B Dirt Movers, Inc<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Fedscreek Surface<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->C<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Active  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Coal (Bituminous)  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="4407296"/><font style="FONT-SIZE:.75em;">4407296</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VA</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->PB Dirt Movers<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Mine No. 6<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Underground         <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->C<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Temporarily Idled  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Coal (Bituminous)  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="4407270"/><font style="FONT-SIZE:.75em;">4407270</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VA</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->PB Dirt Movers, Inc<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface Mine No. 1<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->C<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">NonProducing  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Coal (Bituminous)  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="0203332"/><font style="FONT-SIZE:.75em;">0203332</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>AZ</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Prescott Dirt, LLC<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Sandretto Drive<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="2901986"/><font style="FONT-SIZE:.75em;">2901986</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>NM</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->R D Blankenship Dirt Work LLC<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->R D BLANKENSHIP DIRT WORK<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Active  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="4300768"/><font style="FONT-SIZE:.75em;">4300768</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VT</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->SIMPSON DIRTWORX LLC<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Pettibone Jaw Crusher<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="4300776"/><font style="FONT-SIZE:.75em;">4300776</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>VT</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->SIMPSON DIRTWORX LLC<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Chieftan 1400<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="2302283"/><font style="FONT-SIZE:.75em;">2302283</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>MO</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Spry's Dirt &amp; Gravel, Inc.<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Mike's Money Pit<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td align="center">
#  <form action="/drs/ASP/BasicMineInfostatecounty.asp" method="post" name="search">
#  <input name="MineId" type="hidden" value="2103518"/><font style="FONT-SIZE:.75em;">2103518</font>
#  </form></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT --><b>MN</b><!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Vogt Dirt Service<!-- /DNT -->  </font></td>
#  <td><font style="FONT-SIZE:.75em;"><!-- DNT -->Crusher<!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->Surface             <!-- /DNT --></font></td>
#  <td align="center"><font style="FONT-SIZE:.75em;"><!-- DNT -->M<!-- /DNT --> </font></td>
#  <td><font style="FONT-SIZE:.75em;">Intermittent  </font></td>
#  <td><font style="FONT-SIZE:.75em;">Construction Sand and Gravel  </font></td>
#  <th bgcolor="#000000"><input alt="More Information" border="0" name="submit" src="/drs/images/moreinfo.jpg" type="image"/></th></tr>,
#  <tr>
#  <td bgcolor="#000000" colspan="8"><font style="FONT-SIZE:.75em; color:#FFF"><b>Total Number of Mines Found:</b>  <b>19</b></font></td></tr>]

# %%
for a_result in results:
    tds = a_result.find_all('td')
    if len(tds) >= 3:
        operator_name = tds[2].text.strip()
        print(operator_name)
# Out:
# Newberg Rock & Dirt
# AM Dirtworks & Aggregate Sales
# Dirt Company
# Dirt Con
# Dirt Doctor Inc
# Dirt Works
# Holley Dirt Company, Inc
# Krueger Brothers Gravel & Dirt
# M R Dirt
# M.R. Dirt Inc.
# P B Dirt Movers, Inc
# PB Dirt Movers
# PB Dirt Movers, Inc
# Prescott Dirt, LLC
# R D Blankenship Dirt Work LLC
# SIMPSON DIRTWORX LLC
# SIMPSON DIRTWORX LLC
# Spry's Dirt & Gravel, Inc.
# Vogt Dirt Service

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
for a_result in results:
    tds = a_result.find_all('td')
    if len(tds) >= 3:
        operator_name = tds[2].text.strip()
        print('Name:', operator_name)
        operator_id = a_result.find('input')['value']
        print('ID:', operator_id)
        print("-------")
# Out:
# Name: Newberg Rock & Dirt
# ID: 3503598
# -------
# Name: AM Dirtworks & Aggregate Sales
# ID: 4801789
# -------
# Name: Dirt Company
# ID: 5001797
# -------
# Name: Dirt Con
# ID: 4608254
# -------
# Name: Dirt Doctor Inc
# ID: 2103723
# -------
# Name: Dirt Works
# ID: 4104757
# -------
# Name: Holley Dirt Company, Inc
# ID: 0801306
# -------
# Name: Krueger Brothers Gravel & Dirt
# ID: 3901432
# -------
# Name: M R Dirt
# ID: 3609624
# -------
# Name: M.R. Dirt Inc.
# ID: 3609931
# -------
# Name: P B Dirt Movers, Inc
# ID: 1519799
# -------
# Name: PB Dirt Movers
# ID: 4407296
# -------
# Name: PB Dirt Movers, Inc
# ID: 4407270
# -------
# Name: Prescott Dirt, LLC
# ID: 0203332
# -------
# Name: R D Blankenship Dirt Work LLC
# ID: 2901986
# -------
# Name: SIMPSON DIRTWORX LLC
# ID: 4300768
# -------
# Name: SIMPSON DIRTWORX LLC
# ID: 4300776
# -------
# Name: Spry's Dirt & Gravel, Inc.
# ID: 2302283
# -------
# Name: Vogt Dirt Service
# ID: 2103518
# -------

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.

# %%
mines = []

for a_result in results:
    MSHA = {}
    tds = a_result.find_all('td')
    if len(tds) >= 3:
        operator_name = tds[2].text.strip()
        print('Name:', operator_name)
        MSHA['Name'] = operator_name
        operator_id = a_result.find('input')['value']
        print('ID:', operator_id)
        MSHA['Operator ID'] = operator_id
    if len(tds) >= 4:
        mine_name = tds[3].text.strip()
        print('Mine:', mine_name)
        MSHA['Mine'] = mine_name
    if len(tds) >= 2:
        mine_state = tds[1].text.strip()
        print('State:', mine_state)
        MSHA['State'] = mine_state
    if len(tds) >= 5:
        mine_type = tds[4].text.strip()
        print('Type', mine_type)
        MSHA['Type'] = mine_type
    if len(tds) >= 6:
        coal_metal = tds[5].text.strip()
        print('Coal or Metal:', coal_metal)
        MSHA['Coal or Metal'] = coal_metal
    if len(tds) >= 7:
        mine_status = tds[6].text.strip()
        print('Status:', mine_status)
        MSHA['Status'] = mine_status
    if len(tds) >= 8:
        mine_commodity = tds[7].text.strip()
        print('Commodity:', mine_commodity)
        MSHA['Commodity'] = mine_commodity
        mines.append(MSHA)
        print(MSHA)
        print("-------")
# Out:
# Name: Newberg Rock & Dirt
# ID: 3503598
# Mine: Newberg Rock & Dirt
# State: OR
# Type Surface
# Coal or Metal: M
# Status: Active
# Commodity: Crushed, Broken Stone NEC
# {'Name': 'Newberg Rock & Dirt', 'Operator ID': '3503598', 'Mine': 'Newberg Rock & Dirt', 'State': 'OR', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Active', 'Commodity': 'Crushed, Broken Stone NEC'}
# -------
# Name: AM Dirtworks & Aggregate Sales
# ID: 4801789
# Mine: AM Dirtworks & Aggregate Sales
# State: ND
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': 'AM Dirtworks & Aggregate Sales', 'Operator ID': '4801789', 'Mine': 'AM Dirtworks & Aggregate Sales', 'State': 'ND', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: Dirt Company
# ID: 5001797
# Mine: Bush Pilot
# State: AK
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': 'Dirt Company', 'Operator ID': '5001797', 'Mine': 'Bush Pilot', 'State': 'AK', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: Dirt Con
# ID: 4608254
# Mine: Hog Lick Quarry
# State: WV
# Type Surface
# Coal or Metal: M
# Status: Temporarily Idled
# Commodity: Crushed, Broken Limestone NEC
# {'Name': 'Dirt Con', 'Operator ID': '4608254', 'Mine': 'Hog Lick Quarry', 'State': 'WV', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Temporarily Idled', 'Commodity': 'Crushed, Broken Limestone NEC'}
# -------
# Name: Dirt Doctor Inc
# ID: 2103723
# Mine: Rock Lake Plant
# State: MN
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': 'Dirt Doctor Inc', 'Operator ID': '2103723', 'Mine': 'Rock Lake Plant', 'State': 'MN', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: Dirt Works
# ID: 4104757
# Mine: Portable #1
# State: TX
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': 'Dirt Works', 'Operator ID': '4104757', 'Mine': 'Portable #1', 'State': 'TX', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: Holley Dirt Company, Inc
# ID: 0801306
# Mine: River Road Pit
# State: FL
# Type Surface
# Coal or Metal: M
# Status: Active
# Commodity: Sand, Common
# {'Name': 'Holley Dirt Company, Inc', 'Operator ID': '0801306', 'Mine': 'River Road Pit', 'State': 'FL', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Active', 'Commodity': 'Sand, Common'}
# -------
# Name: Krueger Brothers Gravel & Dirt
# ID: 3901432
# Mine: PORTABLE SCREENER
# State: SD
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': 'Krueger Brothers Gravel & Dirt', 'Operator ID': '3901432', 'Mine': 'PORTABLE SCREENER', 'State': 'SD', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: M R Dirt
# ID: 3609624
# Mine: Forbes Pit
# State: PA
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': 'M R Dirt', 'Operator ID': '3609624', 'Mine': 'Forbes Pit', 'State': 'PA', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: M.R. Dirt Inc.
# ID: 3609931
# Mine: Camptown Quarry
# State: PA
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Dimension Stone NEC
# {'Name': 'M.R. Dirt Inc.', 'Operator ID': '3609931', 'Mine': 'Camptown Quarry', 'State': 'PA', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Dimension Stone NEC'}
# -------
# Name: P B Dirt Movers, Inc
# ID: 1519799
# Mine: Fedscreek Surface
# State: KY
# Type Surface
# Coal or Metal: C
# Status: Active
# Commodity: Coal (Bituminous)
# {'Name': 'P B Dirt Movers, Inc', 'Operator ID': '1519799', 'Mine': 'Fedscreek Surface', 'State': 'KY', 'Type': 'Surface', 'Coal or Metal': 'C', 'Status': 'Active', 'Commodity': 'Coal (Bituminous)'}
# -------
# Name: PB Dirt Movers
# ID: 4407296
# Mine: Mine No. 6
# State: VA
# Type Underground
# Coal or Metal: C
# Status: Temporarily Idled
# Commodity: Coal (Bituminous)
# {'Name': 'PB Dirt Movers', 'Operator ID': '4407296', 'Mine': 'Mine No. 6', 'State': 'VA', 'Type': 'Underground', 'Coal or Metal': 'C', 'Status': 'Temporarily Idled', 'Commodity': 'Coal (Bituminous)'}
# -------
# Name: PB Dirt Movers, Inc
# ID: 4407270
# Mine: Surface Mine No. 1
# State: VA
# Type Surface
# Coal or Metal: C
# Status: NonProducing
# Commodity: Coal (Bituminous)
# {'Name': 'PB Dirt Movers, Inc', 'Operator ID': '4407270', 'Mine': 'Surface Mine No. 1', 'State': 'VA', 'Type': 'Surface', 'Coal or Metal': 'C', 'Status': 'NonProducing', 'Commodity': 'Coal (Bituminous)'}
# -------
# Name: Prescott Dirt, LLC
# ID: 0203332
# Mine: Sandretto Drive
# State: AZ
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': 'Prescott Dirt, LLC', 'Operator ID': '0203332', 'Mine': 'Sandretto Drive', 'State': 'AZ', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: R D Blankenship Dirt Work LLC
# ID: 2901986
# Mine: R D BLANKENSHIP DIRT WORK
# State: NM
# Type Surface
# Coal or Metal: M
# Status: Active
# Commodity: Construction Sand and Gravel
# {'Name': 'R D Blankenship Dirt Work LLC', 'Operator ID': '2901986', 'Mine': 'R D BLANKENSHIP DIRT WORK', 'State': 'NM', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Active', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: SIMPSON DIRTWORX LLC
# ID: 4300768
# Mine: Pettibone Jaw Crusher
# State: VT
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': 'SIMPSON DIRTWORX LLC', 'Operator ID': '4300768', 'Mine': 'Pettibone Jaw Crusher', 'State': 'VT', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: SIMPSON DIRTWORX LLC
# ID: 4300776
# Mine: Chieftan 1400
# State: VT
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': 'SIMPSON DIRTWORX LLC', 'Operator ID': '4300776', 'Mine': 'Chieftan 1400', 'State': 'VT', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: Spry's Dirt & Gravel, Inc.
# ID: 2302283
# Mine: Mike's Money Pit
# State: MO
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': "Spry's Dirt & Gravel, Inc.", 'Operator ID': '2302283', 'Mine': "Mike's Money Pit", 'State': 'MO', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------
# Name: Vogt Dirt Service
# ID: 2103518
# Mine: Crusher
# State: MN
# Type Surface
# Coal or Metal: M
# Status: Intermittent
# Commodity: Construction Sand and Gravel
# {'Name': 'Vogt Dirt Service', 'Operator ID': '2103518', 'Mine': 'Crusher', 'State': 'MN', 'Type': 'Surface', 'Coal or Metal': 'M', 'Status': 'Intermittent', 'Commodity': 'Construction Sand and Gravel'}
# -------

# %% [markdown]
# ### Save that to a CSV

# %%
import pandas as pd

# %%
df = pd.DataFrame(mines)
df.head()
# Out:
#   Coal or Metal                      Commodity  \
# 0             M      Crushed, Broken Stone NEC
# 1             M   Construction Sand and Gravel
# 2             M   Construction Sand and Gravel
# 3             M  Crushed, Broken Limestone NEC
# 4             M   Construction Sand and Gravel
#
#                              Mine                            Name Operator ID  \
# 0             Newberg Rock & Dirt             Newberg Rock & Dirt     3503598
# 1  AM Dirtworks & Aggregate Sales  AM Dirtworks & Aggregate Sales     4801789
# 2                      Bush Pilot                    Dirt Company     5001797
# 3                 Hog Lick Quarry                        Dirt Con     4608254
# 4                 Rock Lake Plant                 Dirt Doctor Inc     2103723
#
#   State             Status     Type
# 0    OR             Active  Surface
# 1    ND       Intermittent  Surface
# 2    AK       Intermittent  Surface
# 3    WV  Temporarily Idled  Surface
# 4    MN       Intermittent  Surface

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
df.to_csv("mines.csv", index=False)

# %%
mines_df = pd.read_csv("mines.csv")
mines_df
# Out:
#    Coal or Metal                      Commodity  \
# 0              M      Crushed, Broken Stone NEC
# 1              M   Construction Sand and Gravel
# 2              M   Construction Sand and Gravel
# 3              M  Crushed, Broken Limestone NEC
# 4              M   Construction Sand and Gravel
# 5              M   Construction Sand and Gravel
# 6              M                   Sand, Common
# 7              M   Construction Sand and Gravel
# 8              M   Construction Sand and Gravel
# 9              M            Dimension Stone NEC
# 10             C              Coal (Bituminous)
# 11             C              Coal (Bituminous)
# 12             C              Coal (Bituminous)
# 13             M   Construction Sand and Gravel
# 14             M   Construction Sand and Gravel
# 15             M   Construction Sand and Gravel
# 16             M   Construction Sand and Gravel
# 17             M   Construction Sand and Gravel
# 18             M   Construction Sand and Gravel
#
#                               Mine                            Name  \
# 0              Newberg Rock & Dirt             Newberg Rock & Dirt
# 1   AM Dirtworks & Aggregate Sales  AM Dirtworks & Aggregate Sales
# 2                       Bush Pilot                    Dirt Company
# 3                  Hog Lick Quarry                        Dirt Con
# 4                  Rock Lake Plant                 Dirt Doctor Inc
# 5                      Portable #1                      Dirt Works
# 6                   River Road Pit        Holley Dirt Company, Inc
# 7                PORTABLE SCREENER  Krueger Brothers Gravel & Dirt
# 8                       Forbes Pit                        M R Dirt
# 9                  Camptown Quarry                  M.R. Dirt Inc.
# 10               Fedscreek Surface            P B Dirt Movers, Inc
# 11                      Mine No. 6                  PB Dirt Movers
# 12              Surface Mine No. 1             PB Dirt Movers, Inc
# 13                 Sandretto Drive              Prescott Dirt, LLC
# 14       R D BLANKENSHIP DIRT WORK   R D Blankenship Dirt Work LLC
# 15           Pettibone Jaw Crusher            SIMPSON DIRTWORX LLC
# 16                   Chieftan 1400            SIMPSON DIRTWORX LLC
# 17                Mike's Money Pit      Spry's Dirt & Gravel, Inc.
# 18                         Crusher               Vogt Dirt Service
#
#     Operator ID State             Status         Type
# 0       3503598    OR             Active      Surface
# 1       4801789    ND       Intermittent      Surface
# 2       5001797    AK       Intermittent      Surface
# 3       4608254    WV  Temporarily Idled      Surface
# 4       2103723    MN       Intermittent      Surface
# 5       4104757    TX       Intermittent      Surface
# 6        801306    FL             Active      Surface
# 7       3901432    SD       Intermittent      Surface
# 8       3609624    PA       Intermittent      Surface
# 9       3609931    PA       Intermittent      Surface
# 10      1519799    KY             Active      Surface
# 11      4407296    VA  Temporarily Idled  Underground
# 12      4407270    VA       NonProducing      Surface
# 13       203332    AZ       Intermittent      Surface
# 14      2901986    NM             Active      Surface
# 15      4300768    VT       Intermittent      Surface
# 16      4300776    VT       Intermittent      Surface
# 17      2302283    MO       Intermittent      Surface
# 18      2103518    MN       Intermittent      Surface
